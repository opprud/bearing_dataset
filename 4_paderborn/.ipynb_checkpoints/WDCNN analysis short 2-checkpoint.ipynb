# %% [markdown]
# # Introduction to dataset
# The experiment was designed and completed in 2014 by Christian Lessmeier, Enge-Rosenblatt, Bayer, & Zimmer, University of Paderborn, Germany.
#
# Data download link: https://mb.uni-paderborn.de/kat/forschung/datacenter/bearing-datacenter/

# %% [markdown]
# ## Data Sets and Download
#
# The main characteristic of the data availible from the Paderborn university are
#
# Synchronously measured motor currents and vibration signals with high resolution and sampling rate of __26 damaged bearing states__ and __6 undamaged (healthy) states__ for reference.
#
# Supportive measurement of speed, torque, radial load, and temperature.
#
# Four different operating conditions (see operating conditions).
# 20 measurements of 4 seconds each for each setting, saved as a MatLab file with a name consisting of the code of the operating condition and the four-digit bearing code (e.g. N15_M07_F10_KA01_1.mat).
#
# Systematic description of the bearing damage by uniform fact sheets and a measuring log, which can be downloaded with the data.
#
# In total, experiments with 32 different bearing damages in ball bearings of type 6203 were performed:
# * Undamaged (healthy) bearings (6x), see Table 6 in (pdf).
# * Artificially damaged bearings (12x), see Table 4 in (pdf).
# * Bearings with real damages caused by accelerated lifetime tests, (14x) see Table 5 in (pdf)

# %% [markdown]
# ## Dataset description & organisation
# each experiments data is stored at the universitys homepage, labelled with the __Bearing Code__ (from the table below).__rar__ further below a number of utility finctions for retrieving det data is implemented

# %% [markdown]
# ### Artificial damages
# The dataset is composed of artificially created and wear based bearing errors.
#
# <img src="doc/ad.png" width="500" height="250">
#
# The artifiaical damages are manufactured using three different methods:
# 1. electric discharge machining, **EDM** (trench of 0.25 mm length
# in rolling direction and depth of 1-2 mm),
# 2. drilling (diameter: 0.9 mm, 2 mm, 3 mm), and
# 3. manual electric engraving (damage length from
# 1-4 mm)
#
# ISO 15243 gives a methodology for the classification of
# bearing damage and failures. The damages are categorized
# into six main damage modes and their sub-modes. The six
# main damage modes are: fatigue, wear, corrosion, electrical
# erosion, plastic deformation, and fracture and cracking.
#
# **Damage extent for a 6203 bearing**
#
# |Damage level | Assigned % value | Limites for 6203 bearing |
# |--- | --- | --- |
#  1 |0-2%|<2mm|
#  2 |2-5%|>2mm|
#  3 |5-15%|>4.5mm|
#  4 |15-35%|>13.5mm|
#  5 |>35%|>31.5mm|

# %% [markdown]
# ### Real Bearing Damage Samples by Accelerated Lifetime Tests
# ball bearings with real
# damages were obtained from an accelerated life time test.
# The accelerated life time test rig consists of a bearing
# housing and an electric motor, which powers a shaft with
# four test bearings of type 6203 in the housing (Figure).
#
# <img src="doc/fig2.png" width="400" height="250">

# %% [markdown]
# ## Dataset summary
# In the tavles below a summary of the availble dataset are summarised
#
# The availible datasets contains following subsets of data, availivble for download, by the name provided in the initial column
#
# ### Healthy bearings
# |Bearing Code | Run-in Period [h] | Radial Load [N] | Speed ​​[min ^ -1] |
# |--- | --- | --- | --- |
#  K001 |> 50 | 1000-3000 | 1500-2000 |
#  K002 | 19 | 3000 | 2900 |
#  K003 | 1 | 3000 | 3000 |
#  K004 | 5 | 3000 | 3000 | |
#  K005 | 10 | 3000 | 3000 | |
#  K006 | 16 | 3000 | 2900 | |
#
# ### Bearings with outer ring damage
# |Bearing Code | Radial Load [N] | Speed ​​[min ^ -1] | Damage method | Damage extent (level) | Damage type |
# |--- | --- | --- | --- | --- | --- |
#  KA01 | - | - | EDM |1||
#  KA03 | - | - | Elec. Engraved|2||
#  KA04 | - | - | HALT|1|Fatigue,pitting|
#  KA05 | - | - | Elec. Engraved|1|
#  KA06 | - | - | Elec. Engraved|2|
#  KA07 | - | - | Drilling |1|
#  KA08 | - | - | Drilling |2|
#  KA09 | - | - | Drilling |2|
#  KA15 | - |-|HALT|1|Plastic deform.:Indentations|
#  KA16 | - |-|HALT|2|fatigue: pitting|
#  KA22 | - |-|HALT|1|fatigue: pitting|
#  KA30 | - |-|HALT|1|Plastic deform.:Indentations|
#
# ### Bearings with inner ring damage
# |Bearing Code | Radial Load [N] | Speed ​​[min ^ -1] | Damage method | Damage extent (level) | Damage type |
# |--- | --- | --- | --- | --- | --- |
#  KI01 | - | - |  EDM |1|
#  KI03 | - | - | Elec. Engraved|1|
#  KI04 | - | - | HALT |1|Fatigue,pitting|
#  KI05 | - | - | Elec. Engraved|1|
#  KI07 | - | - |  Elec. Engraved|2|
#  KI08 | - | - |  Elec. Engraved|2|
#  KI14 | - | - | HALT |1|Fatigue,pitting |
#  KI16 | - | - | HALT |3|Fatigue,pitting |
#  KI17 | - | - | HALT |1|Fatigue,pitting |
#  KI18 | - | - | HALT |2|Fatigue,pitting |
#  KI21 | - | - | HALT |1|Fatigue,pitting |
#
# ### Bearings with combined inner and outer ring damage
# |Bearing Code | Radial Load [N] | Speed ​​[min ^ -1] | Damage method | Damage extent (level) |Damage type |
# |--- | --- | --- | --- | --- | --- |
#  KB23 | - | - | HALT |2|fatigue: pitting|
#  KB24 | - | - | HALT |3|fatigue: pitting|
#  KB27 | - | - | HALT |1|Plastic deform.:Indentations|

# %% [markdown]
# # Code for retrieving datasets

# %% [markdown]
# ## Create data folders & add to ```.gitignore```
#
# No data is to be commited to github since it's not meant for hosting data, just code'
#
# Therefore we add ```data```directory to git ignore list of files

# %%
# create a data folder if such doesnt exist
# !mkdir -p data

#add the data folder to gitignore, to avoid commiting the data
gi_path = '../../../../.gitignore'

# this path, strip the part we need
dir = !pwd
dir = str(dir[0])
s = dir.split('/')
#s
# build working dir string
wd = ('\n' + s[-4] + '/' + s[-3]+ '/' + s[-2]+ '/' + s[-1] + '/data')
wd
# open and append to file
f = open(gi_path, "a")
print(wd, file=f)
f.close()

# %% [markdown]
# ## Retrieve datasets and unpack
# The code below will  download a rar file of interest and return the **unpacked, unshuffled** datasets

# %%
import os
import glob
import errno
import random
#import urllib
import urllib.request as ug
import numpy as np
from scipy.io import loadmat
import patoolib as pa

rarpath = "/usr/local/bin/unrar"

class PDB:
    def __init__(self, exp, rpm, rad_force, torque_mNm, length):
        #    def __init__(self):
        if exp not in ('K001', 'K002', 'K003', 'K004', 'K005', 'K006','KA01','KA02','KA03','KA04','KA05','KA06'
                       ,'KA07','KA08','KA09','KA15','KA16','KA22','KA30','KB23','KB24','KB27','KI01','KI03','KI04'
                       ,'KI05','KI07','KI08','KI14','KI16','KI17','KI18','KI21'):
            print("wrong experiment name: {}".format(exp))
            exit(1)
        if rpm not in ('1500', '900'):
            print("wrong rpm value: {}".format(rpm))
            exit(1)
        if rad_force not in ('1000', '400'):
            print("wrong load value: {}".format(rad_force))
            exit(1)
        if torque_mNm not in ('100', '700'):
            print("wrong torque value: {}".format(torque_mNm))
            exit(1)

        dict_rpm = {'1500': 'N15_', '900': 'N09_', '2900': 'N29_'}
        dict_torq = {'100': 'M01_', '700': 'M07_'}
        dict_load = {'400': 'F04_', '1000': 'F10_'}
        #Labels 1 = healthy bearing, 2 = outer ring damage , 3 = inner ring damage, 4 = combined damage
        dict_labels = {'K0': 1, 'KA': 2, 'KI': 3, 'KB': 4}

        #print(exp[0:2])
        self.y_label = dict_labels[exp[0:2]]
        print("Y is:")
        print(self.y_label)

        filestring = dict_rpm[rpm] + dict_torq[torque_mNm] + dict_load[rad_force]
        print('filestring')
        print(filestring)

        # create reciveing dir names from arguments
        rdir = os.path.join('.', 'data/PDB', exp)  # ,rpm,load)
        fmeta = os.path.join(os.path.dirname('.'), 'metadata.txt')
        all_lines = open(fmeta).readlines()

        lines = []
        for line in all_lines:
            l = line.split()
            # print(l)
            if (l[0] == exp): # and l[1] == rpm and l[2] == rad_force:  # and l[3] == torque_mNm:
                lines.append(l)

        print("l: ")
        print(lines)
        # prepare download
        self.length = length  # sequence length
        #        self._load_and_slice_data2(rdir, lines)
        self._load_and_slice_data(rdir, lines, filestring)

        # shuffle training and test arrays
        shuffle = 0
        if(shuffle):
            self._shuffle()

    def _mkdir(self, path):
        try:
            os.makedirs(path)
        except OSError as exc:
            if exc.errno == errno.EEXIST and os.path.isdir(path):
                pass
            else:
                print("can't create directory '{}''".format(path))
                exit(1)

    def _download(self, fpath, link):
        print("Downloading to: '{}'".format(fpath))
        #urllib.request.urlretrieve(link, fpath)
        ug.urlretrieve(link, fpath)

    def _load_and_slice_data(self, rdir, infos, filestring):

        self.X_train = np.zeros((0, self.length))
        self.X_test = np.zeros((0, self.length))
        self.y_train = []
        self.y_test = []

        ## w
        for idx, info in enumerate(infos):

            # directory to put the raw rar file
            rawdir = os.path.join(rdir, 'raw')
            self._mkdir(rawdir)

            # path to find the file
            fpath = os.path.join(rawdir, info[0] + '.rar')

            # if file already exists, avoid duplicate downloads
            if not os.path.exists(fpath):
                print("no dir/file")
                self._download(fpath, info[3].rstrip('\n'))

            # compressed file to uncompress
            cmpfile = rawdir + '/' + info[0] + '.rar'

            print("file to exrtract is is::")
            print(cmpfile)

            # unpack file
            if not os.path.exists(rdir + '/' + info[0]):
                pa.extract_archive(cmpfile, outdir=rdir, program=rarpath)
            else:
                print("file already extracted, skipping unrar")

            # a list of all files in the extracted dir
            ddir = rdir + '/' + info[0]
            flist_all = os.listdir(ddir)

            # print("filelist:")
            # print(flist_all)

            # use the searchstring, build from the program arguments to find files of interest
            flistsorted = [i for i in flist_all if filestring in i]

            print("sorted filelist:")
            print(flistsorted)

            # now build the dataset from all files of interest
            # iterate through the filelist
            for f in flistsorted:
                # load matlab file
                mat_dict = loadmat(ddir + '/' + f)#,struct_as_record=False)

                # get the values key, tha name of thenactual dataset equal to filename
                #key = list(filter(lambda x: 'N15_M07_F04_' in x, mat_dict.keys()))
                key = list(filter(lambda x: filestring in x, mat_dict.keys()))
                # load data
                #time_series = mat_dict[key[0]][:, 0] #['Y']
                time_series = mat_dict[key[0]]['Y'][0, 0][0, 6][2][:][0]

                idx_last = -(time_series.shape[0] % self.length)
                clips = time_series[:idx_last].reshape(-1, self.length)

                n = clips.shape[0]

                split = 0
                if(split):
                    # 75% train 25%test
                    n_split = int(3 * n / 4)

                    self.X_train = np.vstack((self.X_train, clips[:n_split]))
                    self.X_test = np.vstack((self.X_test, clips[n_split:]))
                    # todo add meaning full label

                    self.y_train += [self.y_label] * n_split
                    self.y_test  += [self.y_label] * (clips.shape[0] - n_split)

                else:
                    self.X_train = np.vstack((self.X_train, clips[:n]))
                    #self.X_test = np.vstack((self.X_test, clips[n_split:]))
                    # todo add meaning full label

                    self.y_train += [self.y_label] * n#_split
                    #self.y_test  += [self.y_label] * (clips.shape[0] - n_split)
                    
    def _shuffle(self):
        # shuffle training samples
        index = list(range(self.X_train.shape[0]))
        random.Random(0).shuffle(index)
        self.X_train = self.X_train[index]
        self.y_train = tuple(self.y_train[i] for i in index)

        # shuffle test samples
        index = list(range(self.X_test.shape[0]))
        random.Random(0).shuffle(index)
        self.X_test = self.X_test[index]
        self.y_test = tuple(self.y_test[i] for i in index)

# %% [markdown]
# ## Determine dataset shape
# In order to be able to detect innerring damage, we expect that at least one full revolution is rquired, for the inner ring to pass through the load zone

# %%
# The signal is digitalized and saved synchronously to the MCS with a sampling rate of 64 kHz.
Fs = 64000
# during the experiments 900 and 1500 RPM are used
ExperimentRPM = 1500

SamplePerRotation = int(Fs*(60/ExperimentRPM))
SamplePerRotation
# Out:
# 2560

# %%
SliceLen = 500#SamplePerRotation

# %% [markdown]
# ## Let's take a look at the data
# the returned object returns an object including test and train data
#
# We want data from a full rotation in the bearing

# %% [markdown]
# ### Build a corpus of data for test and train from artificially made faults
# The used data is build from artificial test data as suggested i the accompanying article.

# %%
#healthy sets
d_healthy_train_1 = PDB('K002','1500','1000','700',SliceLen) #
d_healthy_test_1  = PDB('K001','1500','1000','700',SliceLen)

#outerring
d_OR_test_1  = PDB('KA22','1500','1000','700',SliceLen) 
d_OR_train_2 = PDB('KA01','1500','1000','700',SliceLen) #EDM
d_OR_test_2  = PDB('K004','1500','1000','700',SliceLen)
d_OR_train_3 = PDB('KA05','1500','1000','700',SliceLen) #Elec engraved
d_OR_test_3  = PDB('KA15','1500','1000','700',SliceLen)
d_OR_train_4 = PDB('KA07','1500','1000','700',SliceLen) #Drilling
d_OR_test_4  = PDB('KA30','1500','1000','700',SliceLen)
d_OR_test_5  = PDB('KA16','1500','1000','700',SliceLen) 

#innerring
d_IR_test_1  = PDB('KI14','1500','1000','700',SliceLen)
d_IR_train_2 = PDB('KI01','1500','1000','700',SliceLen) #EDM
d_IR_test_2  = PDB('KI21','1500','1000','700',SliceLen)
d_IR_train_3 = PDB('KI05','1500','1000','700',SliceLen) #Elct engraved
d_IR_test_3  = PDB('KI17','1500','1000','700',SliceLen)
d_IR_train_4 = PDB('KI07','1500','1000','700',SliceLen) #Elec engraved
d_IR_test_4  = PDB('KI18','1500','1000','700',SliceLen)
d_IR_test_5  = PDB('KI16','1500','1000','700',SliceLen) 

print("##################### \n datacollection and unpack done")
# Out:
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K002', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K002.rar']]
# file to exrtract is is::
# ./data/PDB/K002/raw/K002.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K002_12.mat', 'N15_M07_F10_K002_13.mat', 'N15_M07_F10_K002_11.mat', 'N15_M07_F10_K002_10.mat', 'N15_M07_F10_K002_14.mat', 'N15_M07_F10_K002_15.mat', 'N15_M07_F10_K002_17.mat', 'N15_M07_F10_K002_8.mat', 'N15_M07_F10_K002_9.mat', 'N15_M07_F10_K002_16.mat', 'N15_M07_F10_K002_4.mat', 'N15_M07_F10_K002_5.mat', 'N15_M07_F10_K002_18.mat', 'N15_M07_F10_K002_7.mat', 'N15_M07_F10_K002_6.mat', 'N15_M07_F10_K002_19.mat', 'N15_M07_F10_K002_2.mat', 'N15_M07_F10_K002_3.mat', 'N15_M07_F10_K002_20.mat', 'N15_M07_F10_K002_1.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K001', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K001.rar']]
# file to exrtract is is::
# ./data/PDB/K001/raw/K001.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K001_20.mat', 'N15_M07_F10_K001_19.mat', 'N15_M07_F10_K001_9.mat', 'N15_M07_F10_K001_8.mat', 'N15_M07_F10_K001_18.mat', 'N15_M07_F10_K001_15.mat', 'N15_M07_F10_K001_5.mat', 'N15_M07_F10_K001_4.mat', 'N15_M07_F10_K001_14.mat', 'N15_M07_F10_K001_16.mat', 'N15_M07_F10_K001_6.mat', 'N15_M07_F10_K001_7.mat', 'N15_M07_F10_K001_17.mat', 'N15_M07_F10_K001_3.mat', 'N15_M07_F10_K001_13.mat', 'N15_M07_F10_K001_12.mat', 'N15_M07_F10_K001_2.mat', 'N15_M07_F10_K001_10.mat', 'N15_M07_F10_K001_11.mat', 'N15_M07_F10_K001_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA22', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA22.rar']]
# file to exrtract is is::
# ./data/PDB/KA22/raw/KA22.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA22_9.mat', 'N15_M07_F10_KA22_8.mat', 'N15_M07_F10_KA22_20.mat', 'N15_M07_F10_KA22_19.mat', 'N15_M07_F10_KA22_18.mat', 'N15_M07_F10_KA22_16.mat', 'N15_M07_F10_KA22_17.mat', 'N15_M07_F10_KA22_15.mat', 'N15_M07_F10_KA22_14.mat', 'N15_M07_F10_KA22_10.mat', 'N15_M07_F10_KA22_11.mat', 'N15_M07_F10_KA22_13.mat', 'N15_M07_F10_KA22_12.mat', 'N15_M07_F10_KA22_5.mat', 'N15_M07_F10_KA22_4.mat', 'N15_M07_F10_KA22_6.mat', 'N15_M07_F10_KA22_7.mat', 'N15_M07_F10_KA22_3.mat', 'N15_M07_F10_KA22_2.mat', 'N15_M07_F10_KA22_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA01.rar']]
# file to exrtract is is::
# ./data/PDB/KA01/raw/KA01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA01_8.mat', 'N15_M07_F10_KA01_17.mat', 'N15_M07_F10_KA01_16.mat', 'N15_M07_F10_KA01_9.mat', 'N15_M07_F10_KA01_14.mat', 'N15_M07_F10_KA01_15.mat', 'N15_M07_F10_KA01_11.mat', 'N15_M07_F10_KA01_10.mat', 'N15_M07_F10_KA01_12.mat', 'N15_M07_F10_KA01_13.mat', 'N15_M07_F10_KA01_1.mat', 'N15_M07_F10_KA01_2.mat', 'N15_M07_F10_KA01_20.mat', 'N15_M07_F10_KA01_3.mat', 'N15_M07_F10_KA01_7.mat', 'N15_M07_F10_KA01_18.mat', 'N15_M07_F10_KA01_19.mat', 'N15_M07_F10_KA01_6.mat', 'N15_M07_F10_KA01_4.mat', 'N15_M07_F10_KA01_5.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K004', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K004.rar']]
# file to exrtract is is::
# ./data/PDB/K004/raw/K004.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K004_8.mat', 'N15_M07_F10_K004_9.mat', 'N15_M07_F10_K004_10.mat', 'N15_M07_F10_K004_11.mat', 'N15_M07_F10_K004_13.mat', 'N15_M07_F10_K004_12.mat', 'N15_M07_F10_K004_16.mat', 'N15_M07_F10_K004_17.mat', 'N15_M07_F10_K004_15.mat', 'N15_M07_F10_K004_14.mat', 'N15_M07_F10_K004_19.mat', 'N15_M07_F10_K004_18.mat', 'N15_M07_F10_K004_20.mat', 'N15_M07_F10_K004_2.mat', 'N15_M07_F10_K004_3.mat', 'N15_M07_F10_K004_1.mat', 'N15_M07_F10_K004_4.mat', 'N15_M07_F10_K004_5.mat', 'N15_M07_F10_K004_7.mat', 'N15_M07_F10_K004_6.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA05.rar']]
# file to exrtract is is::
# ./data/PDB/KA05/raw/KA05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA05_10.mat', 'N15_M07_F10_KA05_11.mat', 'N15_M07_F10_KA05_13.mat', 'N15_M07_F10_KA05_12.mat', 'N15_M07_F10_KA05_16.mat', 'N15_M07_F10_KA05_17.mat', 'N15_M07_F10_KA05_15.mat', 'N15_M07_F10_KA05_14.mat', 'N15_M07_F10_KA05_9.mat', 'N15_M07_F10_KA05_8.mat', 'N15_M07_F10_KA05_5.mat', 'N15_M07_F10_KA05_4.mat', 'N15_M07_F10_KA05_6.mat', 'N15_M07_F10_KA05_7.mat', 'N15_M07_F10_KA05_3.mat', 'N15_M07_F10_KA05_2.mat', 'N15_M07_F10_KA05_1.mat', 'N15_M07_F10_KA05_19.mat', 'N15_M07_F10_KA05_18.mat', 'N15_M07_F10_KA05_20.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA15', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA15.rar']]
# file to exrtract is is::
# ./data/PDB/KA15/raw/KA15.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA15_7.mat', 'N15_M07_F10_KA15_15.mat', 'N15_M07_F10_KA15_14.mat', 'N15_M07_F10_KA15_6.mat', 'N15_M07_F10_KA15_4.mat', 'N15_M07_F10_KA15_16.mat', 'N15_M07_F10_KA15_17.mat', 'N15_M07_F10_KA15_5.mat', 'N15_M07_F10_KA15_1.mat', 'N15_M07_F10_KA15_13.mat', 'N15_M07_F10_KA15_12.mat', 'N15_M07_F10_KA15_2.mat', 'N15_M07_F10_KA15_10.mat', 'N15_M07_F10_KA15_11.mat', 'N15_M07_F10_KA15_3.mat', 'N15_M07_F10_KA15_20.mat', 'N15_M07_F10_KA15_8.mat', 'N15_M07_F10_KA15_9.mat', 'N15_M07_F10_KA15_19.mat', 'N15_M07_F10_KA15_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA07.rar']]
# file to exrtract is is::
# ./data/PDB/KA07/raw/KA07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA07_15.mat', 'N15_M07_F10_KA07_14.mat', 'N15_M07_F10_KA07_16.mat', 'N15_M07_F10_KA07_17.mat', 'N15_M07_F10_KA07_13.mat', 'N15_M07_F10_KA07_12.mat', 'N15_M07_F10_KA07_10.mat', 'N15_M07_F10_KA07_11.mat', 'N15_M07_F10_KA07_8.mat', 'N15_M07_F10_KA07_9.mat', 'N15_M07_F10_KA07_7.mat', 'N15_M07_F10_KA07_6.mat', 'N15_M07_F10_KA07_4.mat', 'N15_M07_F10_KA07_5.mat', 'N15_M07_F10_KA07_1.mat', 'N15_M07_F10_KA07_2.mat', 'N15_M07_F10_KA07_3.mat', 'N15_M07_F10_KA07_20.mat', 'N15_M07_F10_KA07_19.mat', 'N15_M07_F10_KA07_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA30', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA30.rar']]
# file to exrtract is is::
# ./data/PDB/KA30/raw/KA30.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA30_5.mat', 'N15_M07_F10_KA30_4.mat', 'N15_M07_F10_KA30_6.mat', 'N15_M07_F10_KA30_20.mat', 'N15_M07_F10_KA30_7.mat', 'N15_M07_F10_KA30_3.mat', 'N15_M07_F10_KA30_19.mat', 'N15_M07_F10_KA30_18.mat', 'N15_M07_F10_KA30_2.mat', 'N15_M07_F10_KA30_1.mat', 'N15_M07_F10_KA30_16.mat', 'N15_M07_F10_KA30_17.mat', 'N15_M07_F10_KA30_15.mat', 'N15_M07_F10_KA30_14.mat', 'N15_M07_F10_KA30_10.mat', 'N15_M07_F10_KA30_11.mat', 'N15_M07_F10_KA30_9.mat', 'N15_M07_F10_KA30_13.mat', 'N15_M07_F10_KA30_12.mat', 'N15_M07_F10_KA30_8.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA16.rar']]
# file to exrtract is is::
# ./data/PDB/KA16/raw/KA16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA16_6.mat', 'N15_M07_F10_KA16_7.mat', 'N15_M07_F10_KA16_18.mat', 'N15_M07_F10_KA16_5.mat', 'N15_M07_F10_KA16_4.mat', 'N15_M07_F10_KA16_19.mat', 'N15_M07_F10_KA16_1.mat', 'N15_M07_F10_KA16_20.mat', 'N15_M07_F10_KA16_3.mat', 'N15_M07_F10_KA16_2.mat', 'N15_M07_F10_KA16_12.mat', 'N15_M07_F10_KA16_13.mat', 'N15_M07_F10_KA16_11.mat', 'N15_M07_F10_KA16_10.mat', 'N15_M07_F10_KA16_14.mat', 'N15_M07_F10_KA16_9.mat', 'N15_M07_F10_KA16_8.mat', 'N15_M07_F10_KA16_15.mat', 'N15_M07_F10_KA16_17.mat', 'N15_M07_F10_KA16_16.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI14', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI14.rar']]
# file to exrtract is is::
# ./data/PDB/KI14/raw/KI14.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI14_11.mat', 'N15_M07_F10_KI14_10.mat', 'N15_M07_F10_KI14_12.mat', 'N15_M07_F10_KI14_13.mat', 'N15_M07_F10_KI14_17.mat', 'N15_M07_F10_KI14_16.mat', 'N15_M07_F10_KI14_14.mat', 'N15_M07_F10_KI14_15.mat', 'N15_M07_F10_KI14_2.mat', 'N15_M07_F10_KI14_3.mat', 'N15_M07_F10_KI14_1.mat', 'N15_M07_F10_KI14_4.mat', 'N15_M07_F10_KI14_5.mat', 'N15_M07_F10_KI14_7.mat', 'N15_M07_F10_KI14_6.mat', 'N15_M07_F10_KI14_8.mat', 'N15_M07_F10_KI14_9.mat', 'N15_M07_F10_KI14_18.mat', 'N15_M07_F10_KI14_19.mat', 'N15_M07_F10_KI14_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI01.rar']]
# file to exrtract is is::
# ./data/PDB/KI01/raw/KI01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI01_18.mat', 'N15_M07_F10_KI01_19.mat', 'N15_M07_F10_KI01_20.mat', 'N15_M07_F10_KI01_8.mat', 'N15_M07_F10_KI01_9.mat', 'N15_M07_F10_KI01_7.mat', 'N15_M07_F10_KI01_6.mat', 'N15_M07_F10_KI01_4.mat', 'N15_M07_F10_KI01_5.mat', 'N15_M07_F10_KI01_1.mat', 'N15_M07_F10_KI01_2.mat', 'N15_M07_F10_KI01_3.mat', 'N15_M07_F10_KI01_11.mat', 'N15_M07_F10_KI01_10.mat', 'N15_M07_F10_KI01_12.mat', 'N15_M07_F10_KI01_13.mat', 'N15_M07_F10_KI01_17.mat', 'N15_M07_F10_KI01_16.mat', 'N15_M07_F10_KI01_14.mat', 'N15_M07_F10_KI01_15.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI21', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI21.rar']]
# file to exrtract is is::
# ./data/PDB/KI21/raw/KI21.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI21_8.mat', 'N15_M07_F10_KI21_20.mat', 'N15_M07_F10_KI21_9.mat', 'N15_M07_F10_KI21_18.mat', 'N15_M07_F10_KI21_19.mat', 'N15_M07_F10_KI21_2.mat', 'N15_M07_F10_KI21_17.mat', 'N15_M07_F10_KI21_16.mat', 'N15_M07_F10_KI21_3.mat', 'N15_M07_F10_KI21_1.mat', 'N15_M07_F10_KI21_14.mat', 'N15_M07_F10_KI21_15.mat', 'N15_M07_F10_KI21_4.mat', 'N15_M07_F10_KI21_11.mat', 'N15_M07_F10_KI21_10.mat', 'N15_M07_F10_KI21_5.mat', 'N15_M07_F10_KI21_7.mat', 'N15_M07_F10_KI21_12.mat', 'N15_M07_F10_KI21_13.mat', 'N15_M07_F10_KI21_6.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI05.rar']]
# file to exrtract is is::
# ./data/PDB/KI05/raw/KI05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI05_20.mat', 'N15_M07_F10_KI05_9.mat', 'N15_M07_F10_KI05_8.mat', 'N15_M07_F10_KI05_19.mat', 'N15_M07_F10_KI05_18.mat', 'N15_M07_F10_KI05_16.mat', 'N15_M07_F10_KI05_3.mat', 'N15_M07_F10_KI05_2.mat', 'N15_M07_F10_KI05_17.mat', 'N15_M07_F10_KI05_15.mat', 'N15_M07_F10_KI05_1.mat', 'N15_M07_F10_KI05_14.mat', 'N15_M07_F10_KI05_10.mat', 'N15_M07_F10_KI05_5.mat', 'N15_M07_F10_KI05_4.mat', 'N15_M07_F10_KI05_11.mat', 'N15_M07_F10_KI05_13.mat', 'N15_M07_F10_KI05_6.mat', 'N15_M07_F10_KI05_7.mat', 'N15_M07_F10_KI05_12.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI17', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI17.rar']]
# file to exrtract is is::
# ./data/PDB/KI17/raw/KI17.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI17_3.mat', 'N15_M07_F10_KI17_2.mat', 'N15_M07_F10_KI17_1.mat', 'N15_M07_F10_KI17_5.mat', 'N15_M07_F10_KI17_4.mat', 'N15_M07_F10_KI17_6.mat', 'N15_M07_F10_KI17_7.mat', 'N15_M07_F10_KI17_20.mat', 'N15_M07_F10_KI17_19.mat', 'N15_M07_F10_KI17_18.mat', 'N15_M07_F10_KI17_16.mat', 'N15_M07_F10_KI17_17.mat', 'N15_M07_F10_KI17_15.mat', 'N15_M07_F10_KI17_14.mat', 'N15_M07_F10_KI17_10.mat', 'N15_M07_F10_KI17_11.mat', 'N15_M07_F10_KI17_13.mat', 'N15_M07_F10_KI17_12.mat', 'N15_M07_F10_KI17_9.mat', 'N15_M07_F10_KI17_8.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI07.rar']]
# file to exrtract is is::
# ./data/PDB/KI07/raw/KI07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI07_8.mat', 'N15_M07_F10_KI07_9.mat', 'N15_M07_F10_KI07_19.mat', 'N15_M07_F10_KI07_18.mat', 'N15_M07_F10_KI07_20.mat', 'N15_M07_F10_KI07_1.mat', 'N15_M07_F10_KI07_13.mat', 'N15_M07_F10_KI07_12.mat', 'N15_M07_F10_KI07_2.mat', 'N15_M07_F10_KI07_10.mat', 'N15_M07_F10_KI07_11.mat', 'N15_M07_F10_KI07_3.mat', 'N15_M07_F10_KI07_7.mat', 'N15_M07_F10_KI07_15.mat', 'N15_M07_F10_KI07_14.mat', 'N15_M07_F10_KI07_6.mat', 'N15_M07_F10_KI07_4.mat', 'N15_M07_F10_KI07_16.mat', 'N15_M07_F10_KI07_17.mat', 'N15_M07_F10_KI07_5.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI18', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI18.rar']]
# file to exrtract is is::
# ./data/PDB/KI18/raw/KI18.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI18_11.mat', 'N15_M07_F10_KI18_10.mat', 'N15_M07_F10_KI18_12.mat', 'N15_M07_F10_KI18_13.mat', 'N15_M07_F10_KI18_17.mat', 'N15_M07_F10_KI18_16.mat', 'N15_M07_F10_KI18_14.mat', 'N15_M07_F10_KI18_15.mat', 'N15_M07_F10_KI18_9.mat', 'N15_M07_F10_KI18_8.mat', 'N15_M07_F10_KI18_6.mat', 'N15_M07_F10_KI18_7.mat', 'N15_M07_F10_KI18_5.mat', 'N15_M07_F10_KI18_4.mat', 'N15_M07_F10_KI18_1.mat', 'N15_M07_F10_KI18_3.mat', 'N15_M07_F10_KI18_2.mat', 'N15_M07_F10_KI18_18.mat', 'N15_M07_F10_KI18_19.mat', 'N15_M07_F10_KI18_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI16.rar']]
# file to exrtract is is::
# ./data/PDB/KI16/raw/KI16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI16_14.mat', 'N15_M07_F10_KI16_15.mat', 'N15_M07_F10_KI16_17.mat', 'N15_M07_F10_KI16_16.mat', 'N15_M07_F10_KI16_12.mat', 'N15_M07_F10_KI16_13.mat', 'N15_M07_F10_KI16_11.mat', 'N15_M07_F10_KI16_10.mat', 'N15_M07_F10_KI16_1.mat', 'N15_M07_F10_KI16_3.mat', 'N15_M07_F10_KI16_2.mat', 'N15_M07_F10_KI16_6.mat', 'N15_M07_F10_KI16_7.mat', 'N15_M07_F10_KI16_5.mat', 'N15_M07_F10_KI16_4.mat', 'N15_M07_F10_KI16_9.mat', 'N15_M07_F10_KI16_8.mat', 'N15_M07_F10_KI16_20.mat', 'N15_M07_F10_KI16_18.mat', 'N15_M07_F10_KI16_19.mat']
# #####################
#  datacollection and unpack done

# %%
# These data are from Artificially made faults
X_train = np.concatenate([d_healthy_train_1.X_train, 
                          d_OR_train_2.X_train,d_OR_train_3.X_train, 
                          d_OR_train_4.X_train,
                          d_IR_train_2.X_train,d_IR_train_3.X_train,
                          d_IR_train_4.X_train])

y_train = np.concatenate([d_healthy_train_1.y_train, 
                          d_OR_train_2.y_train,d_OR_train_3.y_train, 
                          d_OR_train_4.y_train, 
                          d_IR_train_2.y_train,d_IR_train_3.y_train,
                          d_IR_train_4.y_train])

#traning data
print(np.shape(X_train))
print(np.shape(y_train))
# Out:
# (59609, 500)
# (59609,)

# %%
#test data, NOTE from the PDB class, when using to generate data, not split by test/training, 
#all data is to be read from "class.<X/y>.train"
X_test = np.concatenate([d_healthy_test_1.X_train, 
                          d_OR_test_2.X_train,d_OR_test_3.X_train, 
                          d_OR_test_4.X_train,
                          d_IR_test_2.X_train,d_IR_test_3.X_train,
                          d_IR_test_4.X_train])

y_test = np.concatenate([d_healthy_test_1.y_train, 
                          d_OR_test_2.y_train,d_OR_test_3.y_train, 
                          d_OR_test_4.y_train, 
                          d_IR_test_2.y_train,d_IR_test_3.y_train,
                          d_IR_test_4.y_train])
#testing data
print(np.shape(X_test))
print(np.shape(y_test))
# Out:
# (60449, 500)
# (60449,)

# %% [markdown]
# ## Compose traning & test datasets

# %% [markdown]
# How much data did we get ?

# %%
def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            # skip if it is symbolic link
            if not os.path.islink(fp):
                total_size += os.path.getsize(fp)

    return total_size

print(get_size('./data'), 'bytes')
# Out:
# 19048829104 bytes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#rcParams['figure.figsize'] = 11.7,8.27

#show every 200 values
plt.plot(y_train[0::200])
plt.show()

# %% [markdown]
# ### Is data biassed / unbalanced
# count the instances in each of the classes

# %%
# any bias ? 
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 9260, 2: 22651, 3: 27698}

# %% [markdown]
# # Build a tensorflow model
# We build the WDCNN model introduced in this article [https://www.researchgate.net/publication/314247372_A_New_Deep_Learning_Model_for_Fault_Diagnosis_with_Good_Anti-Noise_and_Domain_Adaptation_Ability_on_Raw_Vibration_Signals](WDCNN)
#
# The proposed method uses raw vibration signals as input, and uses the wide kernels in the first convolutional layer for extracting features
# and suppressing high frequency noise.<br> Small convolutional kernels in the preceding layers are used
# for multilayer nonlinear mapping.<br> AdaBN is implemented to improve the domain adaptation ability
# of the model.
#
# <img src="doc/wdcnn1.png" width="1000" height="600">

# %%
import tensorflow as tf
#from tensorflow import keras

print(tf.__version__)
# Out:
# 2.0.0

# %%
#from tensorflow import keras as k
from keras import utils

y_train_cat = utils.to_categorical(
    y_train,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)

y_test_cat = utils.to_categorical(
    y_test,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)

#X_train = d1.X_train
#X_test = d1.X_test
# Out:
# Using TensorFlow backend.

# %%
print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train_cat))
print(np.shape(y_test_cat))
# Out:
# (59609, 500)
# (60449, 500)
# (59609, 4)
# (60449, 4)

# %%
#y_test_cat[0::330]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, Conv1D, Flatten, Reshape, MaxPooling1D, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import os

#use GPU acceleration
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"


# Defining the convolution layer
def wdcnn(filters, kernerl_size, strides, conv_padding, pool_padding,  pool_size, BatchNormal):
    """wdcnn Layer neuron

    :param filters: Number of convolution kernels, integer
    :param kernerl_size: Convolution kernel size, integer
    :param strides: Step size, integer
    :param conv_padding: 'same','valid'
    :param pool_padding: 'same','valid'
    :param pool_size: Pooled layer core size, integer
    :param BatchNormal: Whether Batchnormal, Boolean
    :return: model
    """
    model.add(Conv1D(filters=filters, kernel_size=kernerl_size, strides=strides,
                     padding=conv_padding, kernel_regularizer=regularizers.l2(1e-4)))
    if BatchNormal:
        model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=pool_size, padding=pool_padding))
    return model


#### from wdcnnn
BatchNorm = True # Whether to batch normalize
classes = 4#(max(d1.y_train)+1)

# Instantiated sequential model
model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1], ), name='x_input'))
model.add(Reshape((int(X_train.shape[1] / 1), 1), input_shape=(X_train.shape[1], )))
# Set up the input layer, the first layer of convolution. Because you want to specify input_shape, it is released separately.#model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling1D(pool_size=2))
# second layer conv
model = wdcnn(filters=32, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid',  pool_size=2, BatchNormal=BatchNorm)
# Third layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fourth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fifth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='valid',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Flatten from convolution to full connection
model.add(Flatten())

# Flatten from convolution to full connection
model.add(Dense(units=100, activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
# Decrease the output layer
#model.add(Dense(units=num_classes, activation='softmax', kernel_regularizer=regularizers.l2(1e-4)))
model.add(Dense(classes, activation='softmax', name='y_pred'))


# this controls the learning rate
opt = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 500, 1)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 32, 16)            1040
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 16)            64
# _________________________________________________________________
# activation (Activation)      (None, 32, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 32)            1568
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32)            128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 16, 64)            6208
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 64)            256
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 8, 64)             12352
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 64)             256
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 64)             0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 64)             0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 2, 64)             12352
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 64)             256
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 64)             0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 64)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 100)               6500
# _________________________________________________________________
# y_pred (Dense)               (None, 4)                 404
# =================================================================
# Total params: 41,384
# Trainable params: 40,904
# Non-trainable params: 480
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.33, random_state=42)

print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train))
print(np.shape(y_test))
# Out:
# (39938, 500)
# (19671, 500)
# (39938,)
# (19671,)

# %%
ns = 249
l1 = 6*ns
l2 = 60*ns
l3 = 115*ns
l4 = 139*ns


y[0:l1]  = [RUN_IN] *(l1-0)
y[l1:l2] = [RUN_OK] *(l2-l1)
y[l2:l3] = [WEAR] *(l3-l2)
y[l3:]   = [DAMAGE] *(l4-l3)

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=7)

history = model.fit(X_train, y_train_cat, batch_size=50, epochs=100, validation_data=(X_test, y_test_cat), callbacks=[es])
# Out:
# Train on 39938 samples, validate on 19671 samples
# Epoch 1/100
# 39938/39938 [==============================] - 34s 859us/sample - loss: 0.4954 - accuracy: 0.7800 - val_loss: 0.4304 - val_accuracy: 0.7998
# Epoch 2/100
# 39938/39938 [==============================] - 34s 857us/sample - loss: 0.3512 - accuracy: 0.8469 - val_loss: 0.3211 - val_accuracy: 0.8558
# Epoch 3/100
# 39938/39938 [==============================] - 41s 1ms/sample - loss: 0.3133 - accuracy: 0.8680 - val_loss: 0.4350 - val_accuracy: 0.8082
# Epoch 4/100
# 39938/39938 [==============================] - 35s 864us/sample - loss: 0.2864 - accuracy: 0.8817 - val_loss: 0.3479 - val_accuracy: 0.8452
# Epoch 5/100
# 39938/39938 [==============================] - 38s 943us/sample - loss: 0.2733 - accuracy: 0.8891 - val_loss: 0.3068 - val_accuracy: 0.8677
# Epoch 6/100
# 39938/39938 [==============================] - 42s 1ms/sample - loss: 0.2563 - accuracy: 0.8971 - val_loss: 0.4174 - val_accuracy: 0.8402
# Epoch 7/100
# 39938/39938 [==============================] - 38s 951us/sample - loss: 0.2415 - accuracy: 0.9049 - val_loss: 0.3263 - val_accuracy: 0.8680
# Epoch 8/100
# 39938/39938 [==============================] - 34s 862us/sample - loss: 0.2336 - accuracy: 0.9092 - val_loss: 0.2770 - val_accuracy: 0.8888
# Epoch 9/100
# 39938/39938 [==============================] - 37s 922us/sample - loss: 0.2204 - accuracy: 0.9151 - val_loss: 0.2877 - val_accuracy: 0.8829
# Epoch 10/100
# 39938/39938 [==============================] - 35s 874us/sample - loss: 0.2118 - accuracy: 0.9217 - val_loss: 0.2833 - val_accuracy: 0.8853
# Epoch 11/100
# 39938/39938 [==============================] - 43s 1ms/sample - loss: 0.2052 - accuracy: 0.9250 - val_loss: 0.3058 - val_accuracy: 0.8849
# Epoch 12/100
# 39938/39938 [==============================] - 43s 1ms/sample - loss: 0.1983 - accuracy: 0.9298 - val_loss: 0.3292 - val_accuracy: 0.8762
# Epoch 13/100
# 39938/39938 [==============================] - 37s 924us/sample - loss: 0.1884 - accuracy: 0.9348 - val_loss: 0.3153 - val_accuracy: 0.8791
# Epoch 14/100
# 39938/39938 [==============================] - 36s 906us/sample - loss: 0.1817 - accuracy: 0.9372 - val_loss: 0.3194 - val_accuracy: 0.8814
# Epoch 15/100
# 39938/39938 [==============================] - 40s 992us/sample - loss: 0.1711 - accuracy: 0.9428 - val_loss: 0.3761 - val_accuracy: 0.8766
# Epoch 16/100
# 39938/39938 [==============================] - 37s 920us/sample - loss: 0.1713 - accuracy: 0.9441 - val_loss: 0.3809 - val_accuracy: 0.8705
# Epoch 17/100
# 39938/39938 [==============================] - 37s 938us/sample - loss: 0.1618 - accuracy: 0.9489 - val_loss: 0.3967 - val_accuracy: 0.8659
# Epoch 18/100
# 39938/39938 [==============================] - 38s 949us/sample - loss: 0.1571 - accuracy: 0.9517 - val_loss: 0.4845 - val_accuracy: 0.8512
# Epoch 19/100
# 39938/39938 [==============================] - 38s 947us/sample - loss: 0.1526 - accuracy: 0.9545 - val_loss: 0.3336 - val_accuracy: 0.8872
# Epoch 20/100
# 39938/39938 [==============================] - 38s 954us/sample - loss: 0.1513 - accuracy: 0.9553 - val_loss: 0.5505 - val_accuracy: 0.8360
# Epoch 21/100
# 39938/39938 [==============================] - 38s 955us/sample - loss: 0.1463 - accuracy: 0.9577 - val_loss: 0.3768 - val_accuracy: 0.8833
# Epoch 22/100
# 39938/39938 [==============================] - 35s 885us/sample - loss: 0.1395 - accuracy: 0.9612 - val_loss: 0.3678 - val_accuracy: 0.8860
# Epoch 23/100
# 39938/39938 [==============================] - 35s 883us/sample - loss: 0.1407 - accuracy: 0.9601 - val_loss: 0.3805 - val_accuracy: 0.8803
# Epoch 24/100
# 39938/39938 [==============================] - 35s 888us/sample - loss: 0.1386 - accuracy: 0.9633 - val_loss: 0.3762 - val_accuracy: 0.8869
# Epoch 25/100
# 39938/39938 [==============================] - 36s 903us/sample - loss: 0.1312 - accuracy: 0.9666 - val_loss: 0.4214 - val_accuracy: 0.8792
# Epoch 26/100
# 39938/39938 [==============================] - 36s 899us/sample - loss: 0.1269 - accuracy: 0.9683 - val_loss: 0.4267 - val_accuracy: 0.8810
# Epoch 27/100
# 39938/39938 [==============================] - 39s 968us/sample - loss: 0.1305 - accuracy: 0.9665 - val_loss: 0.3946 - val_accuracy: 0.8840
# Epoch 28/100
# 39938/39938 [==============================] - 45s 1ms/sample - loss: 0.1296 - accuracy: 0.9683 - val_loss: 0.4365 - val_accuracy: 0.8775
# Epoch 29/100
# 39938/39938 [==============================] - 36s 895us/sample - loss: 0.1297 - accuracy: 0.9679 - val_loss: 0.4616 - val_accuracy: 0.8636
# Epoch 30/100
# 39938/39938 [==============================] - 36s 898us/sample - loss: 0.1249 - accuracy: 0.9697 - val_loss: 0.4998 - val_accuracy: 0.8663
# Epoch 31/100
# 39938/39938 [==============================] - 40s 1ms/sample - loss: 0.1235 - accuracy: 0.9715 - val_loss: 0.5292 - val_accuracy: 0.8640
# Epoch 32/100
# 39938/39938 [==============================] - 37s 928us/sample - loss: 0.1249 - accuracy: 0.9709 - val_loss: 0.5214 - val_accuracy: 0.8665
# Epoch 33/100
# 39938/39938 [==============================] - 36s 890us/sample - loss: 0.1268 - accuracy: 0.9699 - val_loss: 0.4783 - val_accuracy: 0.8755
# Epoch 34/100
# 39938/39938 [==============================] - 36s 892us/sample - loss: 0.1189 - accuracy: 0.9746 - val_loss: 0.4304 - val_accuracy: 0.8818
# Epoch 35/100
# 39938/39938 [==============================] - 36s 895us/sample - loss: 0.1203 - accuracy: 0.9739 - val_loss: 0.4911 - val_accuracy: 0.8753
# Epoch 36/100
# 39938/39938 [==============================] - 37s 916us/sample - loss: 0.1201 - accuracy: 0.9748 - val_loss: 0.5050 - val_accuracy: 0.8644
# Epoch 37/100
# 39938/39938 [==============================] - 36s 900us/sample - loss: 0.1185 - accuracy: 0.9752 - val_loss: 0.4820 - val_accuracy: 0.8775
# Epoch 38/100
# 39938/39938 [==============================] - 38s 948us/sample - loss: 0.1183 - accuracy: 0.9746 - val_loss: 0.4851 - val_accuracy: 0.8723
# Epoch 39/100
# 39938/39938 [==============================] - 36s 898us/sample - loss: 0.1174 - accuracy: 0.9757 - val_loss: 0.5069 - val_accuracy: 0.8763
# Epoch 40/100
# 39938/39938 [==============================] - 36s 903us/sample - loss: 0.1191 - accuracy: 0.9754 - val_loss: 0.5261 - val_accuracy: 0.8626
# Epoch 41/100
# 39938/39938 [==============================] - 35s 879us/sample - loss: 0.1150 - accuracy: 0.9769 - val_loss: 0.4798 - val_accuracy: 0.8748
# Epoch 42/100
# 39938/39938 [==============================] - 32s 802us/sample - loss: 0.1182 - accuracy: 0.9762 - val_loss: 0.5194 - val_accuracy: 0.8669
# Epoch 43/100
# 39938/39938 [==============================] - 32s 804us/sample - loss: 0.1183 - accuracy: 0.9761 - val_loss: 0.4978 - val_accuracy: 0.8685
# Epoch 44/100
# 39938/39938 [==============================] - 34s 849us/sample - loss: 0.1160 - accuracy: 0.9772 - val_loss: 0.4682 - val_accuracy: 0.8837
# Epoch 45/100
# 39938/39938 [==============================] - 33s 814us/sample - loss: 0.1161 - accuracy: 0.9770 - val_loss: 0.4747 - val_accuracy: 0.8779
# Epoch 46/100
# 39938/39938 [==============================] - 32s 802us/sample - loss: 0.1165 - accuracy: 0.9777 - val_loss: 0.6902 - val_accuracy: 0.8472
# Epoch 47/100
# 39938/39938 [==============================] - 32s 798us/sample - loss: 0.1150 - accuracy: 0.9777 - val_loss: 0.4885 - val_accuracy: 0.8823
# Epoch 48/100
# 39938/39938 [==============================] - 32s 803us/sample - loss: 0.1157 - accuracy: 0.9779 - val_loss: 0.5103 - val_accuracy: 0.8768
# Epoch 49/100
# 39938/39938 [==============================] - 32s 805us/sample - loss: 0.1106 - accuracy: 0.9809 - val_loss: 0.4856 - val_accuracy: 0.8828
# Epoch 50/100
# 39938/39938 [==============================] - 34s 843us/sample - loss: 0.1139 - accuracy: 0.9795 - val_loss: 0.4975 - val_accuracy: 0.8755
# Epoch 51/100
# 39938/39938 [==============================] - 33s 837us/sample - loss: 0.1153 - accuracy: 0.9791 - val_loss: 0.4723 - val_accuracy: 0.8832
# Epoch 52/100
# 39938/39938 [==============================] - 37s 933us/sample - loss: 0.1137 - accuracy: 0.9791 - val_loss: 0.5393 - val_accuracy: 0.8744
# Epoch 53/100
# 39938/39938 [==============================] - 37s 921us/sample - loss: 0.1139 - accuracy: 0.9795 - val_loss: 0.5395 - val_accuracy: 0.8722
# Epoch 54/100
# 39938/39938 [==============================] - 37s 919us/sample - loss: 0.1141 - accuracy: 0.9791 - val_loss: 0.4848 - val_accuracy: 0.8811
# Epoch 55/100
# 39938/39938 [==============================] - 35s 883us/sample - loss: 0.1174 - accuracy: 0.9782 - val_loss: 0.4984 - val_accuracy: 0.8794
# Epoch 56/100
# 39938/39938 [==============================] - 34s 848us/sample - loss: 0.1100 - accuracy: 0.9819 - val_loss: 0.6199 - val_accuracy: 0.8636
# Epoch 57/100
# 39938/39938 [==============================] - 33s 816us/sample - loss: 0.1149 - accuracy: 0.9791 - val_loss: 0.4852 - val_accuracy: 0.8819
# Epoch 58/100
# 39938/39938 [==============================] - 35s 886us/sample - loss: 0.1137 - accuracy: 0.9801 - val_loss: 0.5119 - val_accuracy: 0.8792
# Epoch 59/100
# 39938/39938 [==============================] - 38s 961us/sample - loss: 0.1135 - accuracy: 0.9804 - val_loss: 0.5114 - val_accuracy: 0.8797
# Epoch 60/100
# 39938/39938 [==============================] - 40s 1ms/sample - loss: 0.1123 - accuracy: 0.9806 - val_loss: 0.4751 - val_accuracy: 0.8847
# Epoch 61/100
# 39938/39938 [==============================] - 36s 910us/sample - loss: 0.1158 - accuracy: 0.9801 - val_loss: 0.4756 - val_accuracy: 0.8829
# Epoch 62/100
# 39938/39938 [==============================] - 37s 939us/sample - loss: 0.1110 - accuracy: 0.9813 - val_loss: 0.5033 - val_accuracy: 0.8834
# Epoch 63/100
# 39938/39938 [==============================] - 42s 1ms/sample - loss: 0.1097 - accuracy: 0.9811 - val_loss: 0.6463 - val_accuracy: 0.8681
# Epoch 64/100
# 39938/39938 [==============================] - 37s 929us/sample - loss: 0.1144 - accuracy: 0.9799 - val_loss: 0.5034 - val_accuracy: 0.8802
# Epoch 65/100
# 39938/39938 [==============================] - 36s 908us/sample - loss: 0.1162 - accuracy: 0.9801 - val_loss: 0.5184 - val_accuracy: 0.8722
# Epoch 66/100
# 39938/39938 [==============================] - 35s 871us/sample - loss: 0.1099 - accuracy: 0.9823 - val_loss: 0.5201 - val_accuracy: 0.8801
# Epoch 67/100
# 39938/39938 [==============================] - 37s 915us/sample - loss: 0.1098 - accuracy: 0.9821 - val_loss: 0.6935 - val_accuracy: 0.8516
# Epoch 68/100
# 39938/39938 [==============================] - 39s 984us/sample - loss: 0.1108 - accuracy: 0.9815 - val_loss: 0.5805 - val_accuracy: 0.8711
# Epoch 69/100
# 39938/39938 [==============================] - 38s 962us/sample - loss: 0.1149 - accuracy: 0.9804 - val_loss: 0.4818 - val_accuracy: 0.8846
# Epoch 70/100
# 39938/39938 [==============================] - 36s 897us/sample - loss: 0.1094 - accuracy: 0.9822 - val_loss: 0.5317 - val_accuracy: 0.8718
# Epoch 71/100
# 39938/39938 [==============================] - 35s 880us/sample - loss: 0.1120 - accuracy: 0.9817 - val_loss: 0.5985 - val_accuracy: 0.8651
# Epoch 72/100
# 39938/39938 [==============================] - 37s 933us/sample - loss: 0.1076 - accuracy: 0.9829 - val_loss: 0.5633 - val_accuracy: 0.8693
# Epoch 73/100
# 39938/39938 [==============================] - 39s 975us/sample - loss: 0.1091 - accuracy: 0.9825 - val_loss: 0.5369 - val_accuracy: 0.8810
# Epoch 74/100
# 39938/39938 [==============================] - 36s 899us/sample - loss: 0.1082 - accuracy: 0.9830 - val_loss: 0.5127 - val_accuracy: 0.8818
# Epoch 75/100
# 39938/39938 [==============================] - 37s 914us/sample - loss: 0.1116 - accuracy: 0.9825 - val_loss: 0.4755 - val_accuracy: 0.8823
# Epoch 76/100
# 39938/39938 [==============================] - 33s 835us/sample - loss: 0.1084 - accuracy: 0.9830 - val_loss: 0.7244 - val_accuracy: 0.8625
# Epoch 77/100
# 39938/39938 [==============================] - 35s 877us/sample - loss: 0.1088 - accuracy: 0.9830 - val_loss: 0.5481 - val_accuracy: 0.8738
# Epoch 78/100
# 39938/39938 [==============================] - 41s 1ms/sample - loss: 0.1107 - accuracy: 0.9823 - val_loss: 0.6087 - val_accuracy: 0.8620
# Epoch 79/100
# 39938/39938 [==============================] - 36s 911us/sample - loss: 0.1113 - accuracy: 0.9822 - val_loss: 0.5891 - val_accuracy: 0.8758
# Epoch 80/100
# 39938/39938 [==============================] - 35s 879us/sample - loss: 0.1116 - accuracy: 0.9817 - val_loss: 0.5043 - val_accuracy: 0.8834
# Epoch 81/100
# 39938/39938 [==============================] - 40s 1ms/sample - loss: 0.1118 - accuracy: 0.9820 - val_loss: 0.5230 - val_accuracy: 0.8798
# Epoch 82/100
# 39938/39938 [==============================] - 44s 1ms/sample - loss: 0.1084 - accuracy: 0.9835 - val_loss: 0.5972 - val_accuracy: 0.8757
# Epoch 83/100
# 39938/39938 [==============================] - 65s 2ms/sample - loss: 0.1088 - accuracy: 0.9835 - val_loss: 0.5025 - val_accuracy: 0.8813
# Epoch 84/100
# 39938/39938 [==============================] - 76s 2ms/sample - loss: 0.1111 - accuracy: 0.9829 - val_loss: 0.5044 - val_accuracy: 0.8827
# Epoch 85/100
# 39938/39938 [==============================] - 81s 2ms/sample - loss: 0.1101 - accuracy: 0.9832 - val_loss: 0.5855 - val_accuracy: 0.8733
# Epoch 86/100
# 39938/39938 [==============================] - 72s 2ms/sample - loss: 0.1113 - accuracy: 0.9818 - val_loss: 0.5696 - val_accuracy: 0.8722
# Epoch 87/100
# 39938/39938 [==============================] - 58s 1ms/sample - loss: 0.1086 - accuracy: 0.9835 - val_loss: 0.5008 - val_accuracy: 0.8820
# Epoch 88/100
# 39938/39938 [==============================] - 62s 2ms/sample - loss: 0.1064 - accuracy: 0.9838 - val_loss: 0.5229 - val_accuracy: 0.8828
# Epoch 89/100
# 39938/39938 [==============================] - 76s 2ms/sample - loss: 0.1162 - accuracy: 0.9810 - val_loss: 0.5109 - val_accuracy: 0.8763
# Epoch 90/100
# 39938/39938 [==============================] - 67s 2ms/sample - loss: 0.1050 - accuracy: 0.9848 - val_loss: 0.6048 - val_accuracy: 0.8679
# Epoch 91/100
# 39938/39938 [==============================] - 62s 2ms/sample - loss: 0.1095 - accuracy: 0.9836 - val_loss: 0.6098 - val_accuracy: 0.8642
# Epoch 92/100
# 39938/39938 [==============================] - 63s 2ms/sample - loss: 0.1094 - accuracy: 0.9829 - val_loss: 0.5827 - val_accuracy: 0.8717
# Epoch 93/100
# 39938/39938 [==============================] - 59s 1ms/sample - loss: 0.1055 - accuracy: 0.9842 - val_loss: 0.9551 - val_accuracy: 0.8475
# Epoch 94/100
# 39938/39938 [==============================] - 53s 1ms/sample - loss: 0.1083 - accuracy: 0.9835 - val_loss: 0.5329 - val_accuracy: 0.8799
# Epoch 95/100
# 39938/39938 [==============================] - 51s 1ms/sample - loss: 0.1077 - accuracy: 0.9838 - val_loss: 0.5387 - val_accuracy: 0.8754
# Epoch 96/100
# 39938/39938 [==============================] - 55s 1ms/sample - loss: 0.1104 - accuracy: 0.9829 - val_loss: 0.5036 - val_accuracy: 0.8829
# Epoch 97/100
# 39938/39938 [==============================] - 61s 2ms/sample - loss: 0.1074 - accuracy: 0.9839 - val_loss: 0.6424 - val_accuracy: 0.8706
# Epoch 98/100
# 39938/39938 [==============================] - 64s 2ms/sample - loss: 0.1111 - accuracy: 0.9828 - val_loss: 0.5102 - val_accuracy: 0.8833
# Epoch 99/100
# 39938/39938 [==============================] - 67s 2ms/sample - loss: 0.1057 - accuracy: 0.9843 - val_loss: 0.5267 - val_accuracy: 0.8815
# Epoch 100/100
# 39938/39938 [==============================] - 44s 1ms/sample - loss: 0.1077 - accuracy: 0.9841 - val_loss: 0.5964 - val_accuracy: 0.8778

# %%
history = model.fit(X_train, y_train_cat, batch_size=50, epochs=100, validation_data=(X_test, y_test_cat))

# %% [markdown]
# ## Evaluate model 1 on artificial fault data
# predict, asess, and create a consfusion matrix

# %%
#X_test
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, y_test_cat, batch_size=128)
#results = model.evaluate(X_test, Y_test, batch_size=50)
print('test loss, test acc:', results)
# Out:
# # Evaluate on test data
# 19671/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test loss, test acc: [0.5964195777071092, 0.8777896]

# %%
model.save('model_1_inputw500.h5')

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.plot()#tight_layout()

# %%
# import for showing the confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

results = model.predict(X_test, 128)# batch_size=HParams.test_batch_size)

# convert from class probabilities to actual class predictions
predicted_classes = np.argmax(results, axis=1)

# Names of predicted classes
class_names = [ "OK", "Outer", "Inner", "Combined"]
#Labels 1 = healthy bearing, 2 = outer ring damage , 3 = inner ring damage, 4 = combined damage


# Generate the confusion matrix
cnf_matrix = confusion_matrix(y_test, predicted_classes)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1560  100 1469]
#  [  29 7163  190]
#  [ 386  230 8544]]

# %% [markdown]
# ### Conclusion on the results
# The above model was trained with a small inpout dataset-slice-width of 500 samples, and accordingly shape of the first input layer <br>
# This corresponds to roughly 1/5 of a full resolution when sampling at 64KHz, and therefore inne ring damages are not seen as distinct, since the damage will not roll through the load zone more than every 5'th time.<br>
# The close to 50% accuracy may suggest **some overfitting of the model** ?
#
# This model was build with :
# * Total params: 41,384
# * Trainable params: 40,904
# * Non-trainable params: 480
#
# And a result of :
#     **test loss, test acc: [0.5964195777071092, 0.8777896]**

# %% [markdown]
# ## Evaluate model, with wider input layer, artificial fault data
# Now redo with a full revolution of samples, as input shape<br>
# The first exepriment used 500 as input dimension, now we ramp it up to 2560 (samples from a full revolution at 150RPM, Fs 64KHz), resulting in a larger model with
# * Total params: 92,584
# * Trainable params: 92,104
# * Non-trainable params: 480

# %%
SliceLen = SamplePerRotation
#healthy sets
d_healthy_train_1 = PDB('K002','1500','1000','700',SliceLen)
d_healthy_test_1  = PDB('K001','1500','1000','700',SliceLen)

#outerring
d_OR_test_1  = PDB('KA22','1500','1000','700',SliceLen)
d_OR_train_2 = PDB('KA01','1500','1000','700',SliceLen)
d_OR_test_2  = PDB('K004','1500','1000','700',SliceLen)
d_OR_train_3 = PDB('KA05','1500','1000','700',SliceLen)
d_OR_test_3  = PDB('KA15','1500','1000','700',SliceLen)
d_OR_train_4 = PDB('KA07','1500','1000','700',SliceLen)
d_OR_test_4  = PDB('KA30','1500','1000','700',SliceLen)
d_OR_test_5  = PDB('KA16','1500','1000','700',SliceLen)

#innerring
d_IR_test_1  = PDB('KI14','1500','1000','700',SliceLen)
d_IR_train_2 = PDB('KI01','1500','1000','700',SliceLen)
d_IR_test_2  = PDB('KI21','1500','1000','700',SliceLen)
d_IR_train_3 = PDB('KI05','1500','1000','700',SliceLen)
d_IR_test_3  = PDB('KI17','1500','1000','700',SliceLen)
d_IR_train_4 = PDB('KI07','1500','1000','700',SliceLen)
d_IR_test_4  = PDB('KI18','1500','1000','700',SliceLen)
d_IR_test_5  = PDB('KI16','1500','1000','700',SliceLen)


print("##################### \n datacollection and unpack done")
# Out:
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K002', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K002.rar']]
# file to exrtract is is::
# ./data/PDB/K002/raw/K002.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K002_12.mat', 'N15_M07_F10_K002_13.mat', 'N15_M07_F10_K002_11.mat', 'N15_M07_F10_K002_10.mat', 'N15_M07_F10_K002_14.mat', 'N15_M07_F10_K002_15.mat', 'N15_M07_F10_K002_17.mat', 'N15_M07_F10_K002_8.mat', 'N15_M07_F10_K002_9.mat', 'N15_M07_F10_K002_16.mat', 'N15_M07_F10_K002_4.mat', 'N15_M07_F10_K002_5.mat', 'N15_M07_F10_K002_18.mat', 'N15_M07_F10_K002_7.mat', 'N15_M07_F10_K002_6.mat', 'N15_M07_F10_K002_19.mat', 'N15_M07_F10_K002_2.mat', 'N15_M07_F10_K002_3.mat', 'N15_M07_F10_K002_20.mat', 'N15_M07_F10_K002_1.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K001', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K001.rar']]
# file to exrtract is is::
# ./data/PDB/K001/raw/K001.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K001_20.mat', 'N15_M07_F10_K001_19.mat', 'N15_M07_F10_K001_9.mat', 'N15_M07_F10_K001_8.mat', 'N15_M07_F10_K001_18.mat', 'N15_M07_F10_K001_15.mat', 'N15_M07_F10_K001_5.mat', 'N15_M07_F10_K001_4.mat', 'N15_M07_F10_K001_14.mat', 'N15_M07_F10_K001_16.mat', 'N15_M07_F10_K001_6.mat', 'N15_M07_F10_K001_7.mat', 'N15_M07_F10_K001_17.mat', 'N15_M07_F10_K001_3.mat', 'N15_M07_F10_K001_13.mat', 'N15_M07_F10_K001_12.mat', 'N15_M07_F10_K001_2.mat', 'N15_M07_F10_K001_10.mat', 'N15_M07_F10_K001_11.mat', 'N15_M07_F10_K001_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA22', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA22.rar']]
# file to exrtract is is::
# ./data/PDB/KA22/raw/KA22.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA22_9.mat', 'N15_M07_F10_KA22_8.mat', 'N15_M07_F10_KA22_20.mat', 'N15_M07_F10_KA22_19.mat', 'N15_M07_F10_KA22_18.mat', 'N15_M07_F10_KA22_16.mat', 'N15_M07_F10_KA22_17.mat', 'N15_M07_F10_KA22_15.mat', 'N15_M07_F10_KA22_14.mat', 'N15_M07_F10_KA22_10.mat', 'N15_M07_F10_KA22_11.mat', 'N15_M07_F10_KA22_13.mat', 'N15_M07_F10_KA22_12.mat', 'N15_M07_F10_KA22_5.mat', 'N15_M07_F10_KA22_4.mat', 'N15_M07_F10_KA22_6.mat', 'N15_M07_F10_KA22_7.mat', 'N15_M07_F10_KA22_3.mat', 'N15_M07_F10_KA22_2.mat', 'N15_M07_F10_KA22_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA01.rar']]
# file to exrtract is is::
# ./data/PDB/KA01/raw/KA01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA01_8.mat', 'N15_M07_F10_KA01_17.mat', 'N15_M07_F10_KA01_16.mat', 'N15_M07_F10_KA01_9.mat', 'N15_M07_F10_KA01_14.mat', 'N15_M07_F10_KA01_15.mat', 'N15_M07_F10_KA01_11.mat', 'N15_M07_F10_KA01_10.mat', 'N15_M07_F10_KA01_12.mat', 'N15_M07_F10_KA01_13.mat', 'N15_M07_F10_KA01_1.mat', 'N15_M07_F10_KA01_2.mat', 'N15_M07_F10_KA01_20.mat', 'N15_M07_F10_KA01_3.mat', 'N15_M07_F10_KA01_7.mat', 'N15_M07_F10_KA01_18.mat', 'N15_M07_F10_KA01_19.mat', 'N15_M07_F10_KA01_6.mat', 'N15_M07_F10_KA01_4.mat', 'N15_M07_F10_KA01_5.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K004', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K004.rar']]
# file to exrtract is is::
# ./data/PDB/K004/raw/K004.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K004_8.mat', 'N15_M07_F10_K004_9.mat', 'N15_M07_F10_K004_10.mat', 'N15_M07_F10_K004_11.mat', 'N15_M07_F10_K004_13.mat', 'N15_M07_F10_K004_12.mat', 'N15_M07_F10_K004_16.mat', 'N15_M07_F10_K004_17.mat', 'N15_M07_F10_K004_15.mat', 'N15_M07_F10_K004_14.mat', 'N15_M07_F10_K004_19.mat', 'N15_M07_F10_K004_18.mat', 'N15_M07_F10_K004_20.mat', 'N15_M07_F10_K004_2.mat', 'N15_M07_F10_K004_3.mat', 'N15_M07_F10_K004_1.mat', 'N15_M07_F10_K004_4.mat', 'N15_M07_F10_K004_5.mat', 'N15_M07_F10_K004_7.mat', 'N15_M07_F10_K004_6.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA05.rar']]
# file to exrtract is is::
# ./data/PDB/KA05/raw/KA05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA05_10.mat', 'N15_M07_F10_KA05_11.mat', 'N15_M07_F10_KA05_13.mat', 'N15_M07_F10_KA05_12.mat', 'N15_M07_F10_KA05_16.mat', 'N15_M07_F10_KA05_17.mat', 'N15_M07_F10_KA05_15.mat', 'N15_M07_F10_KA05_14.mat', 'N15_M07_F10_KA05_9.mat', 'N15_M07_F10_KA05_8.mat', 'N15_M07_F10_KA05_5.mat', 'N15_M07_F10_KA05_4.mat', 'N15_M07_F10_KA05_6.mat', 'N15_M07_F10_KA05_7.mat', 'N15_M07_F10_KA05_3.mat', 'N15_M07_F10_KA05_2.mat', 'N15_M07_F10_KA05_1.mat', 'N15_M07_F10_KA05_19.mat', 'N15_M07_F10_KA05_18.mat', 'N15_M07_F10_KA05_20.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA15', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA15.rar']]
# file to exrtract is is::
# ./data/PDB/KA15/raw/KA15.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA15_7.mat', 'N15_M07_F10_KA15_15.mat', 'N15_M07_F10_KA15_14.mat', 'N15_M07_F10_KA15_6.mat', 'N15_M07_F10_KA15_4.mat', 'N15_M07_F10_KA15_16.mat', 'N15_M07_F10_KA15_17.mat', 'N15_M07_F10_KA15_5.mat', 'N15_M07_F10_KA15_1.mat', 'N15_M07_F10_KA15_13.mat', 'N15_M07_F10_KA15_12.mat', 'N15_M07_F10_KA15_2.mat', 'N15_M07_F10_KA15_10.mat', 'N15_M07_F10_KA15_11.mat', 'N15_M07_F10_KA15_3.mat', 'N15_M07_F10_KA15_20.mat', 'N15_M07_F10_KA15_8.mat', 'N15_M07_F10_KA15_9.mat', 'N15_M07_F10_KA15_19.mat', 'N15_M07_F10_KA15_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA07.rar']]
# file to exrtract is is::
# ./data/PDB/KA07/raw/KA07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA07_15.mat', 'N15_M07_F10_KA07_14.mat', 'N15_M07_F10_KA07_16.mat', 'N15_M07_F10_KA07_17.mat', 'N15_M07_F10_KA07_13.mat', 'N15_M07_F10_KA07_12.mat', 'N15_M07_F10_KA07_10.mat', 'N15_M07_F10_KA07_11.mat', 'N15_M07_F10_KA07_8.mat', 'N15_M07_F10_KA07_9.mat', 'N15_M07_F10_KA07_7.mat', 'N15_M07_F10_KA07_6.mat', 'N15_M07_F10_KA07_4.mat', 'N15_M07_F10_KA07_5.mat', 'N15_M07_F10_KA07_1.mat', 'N15_M07_F10_KA07_2.mat', 'N15_M07_F10_KA07_3.mat', 'N15_M07_F10_KA07_20.mat', 'N15_M07_F10_KA07_19.mat', 'N15_M07_F10_KA07_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA30', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA30.rar']]
# file to exrtract is is::
# ./data/PDB/KA30/raw/KA30.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA30_5.mat', 'N15_M07_F10_KA30_4.mat', 'N15_M07_F10_KA30_6.mat', 'N15_M07_F10_KA30_20.mat', 'N15_M07_F10_KA30_7.mat', 'N15_M07_F10_KA30_3.mat', 'N15_M07_F10_KA30_19.mat', 'N15_M07_F10_KA30_18.mat', 'N15_M07_F10_KA30_2.mat', 'N15_M07_F10_KA30_1.mat', 'N15_M07_F10_KA30_16.mat', 'N15_M07_F10_KA30_17.mat', 'N15_M07_F10_KA30_15.mat', 'N15_M07_F10_KA30_14.mat', 'N15_M07_F10_KA30_10.mat', 'N15_M07_F10_KA30_11.mat', 'N15_M07_F10_KA30_9.mat', 'N15_M07_F10_KA30_13.mat', 'N15_M07_F10_KA30_12.mat', 'N15_M07_F10_KA30_8.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA16.rar']]
# file to exrtract is is::
# ./data/PDB/KA16/raw/KA16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA16_6.mat', 'N15_M07_F10_KA16_7.mat', 'N15_M07_F10_KA16_18.mat', 'N15_M07_F10_KA16_5.mat', 'N15_M07_F10_KA16_4.mat', 'N15_M07_F10_KA16_19.mat', 'N15_M07_F10_KA16_1.mat', 'N15_M07_F10_KA16_20.mat', 'N15_M07_F10_KA16_3.mat', 'N15_M07_F10_KA16_2.mat', 'N15_M07_F10_KA16_12.mat', 'N15_M07_F10_KA16_13.mat', 'N15_M07_F10_KA16_11.mat', 'N15_M07_F10_KA16_10.mat', 'N15_M07_F10_KA16_14.mat', 'N15_M07_F10_KA16_9.mat', 'N15_M07_F10_KA16_8.mat', 'N15_M07_F10_KA16_15.mat', 'N15_M07_F10_KA16_17.mat', 'N15_M07_F10_KA16_16.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI14', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI14.rar']]
# file to exrtract is is::
# ./data/PDB/KI14/raw/KI14.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI14_11.mat', 'N15_M07_F10_KI14_10.mat', 'N15_M07_F10_KI14_12.mat', 'N15_M07_F10_KI14_13.mat', 'N15_M07_F10_KI14_17.mat', 'N15_M07_F10_KI14_16.mat', 'N15_M07_F10_KI14_14.mat', 'N15_M07_F10_KI14_15.mat', 'N15_M07_F10_KI14_2.mat', 'N15_M07_F10_KI14_3.mat', 'N15_M07_F10_KI14_1.mat', 'N15_M07_F10_KI14_4.mat', 'N15_M07_F10_KI14_5.mat', 'N15_M07_F10_KI14_7.mat', 'N15_M07_F10_KI14_6.mat', 'N15_M07_F10_KI14_8.mat', 'N15_M07_F10_KI14_9.mat', 'N15_M07_F10_KI14_18.mat', 'N15_M07_F10_KI14_19.mat', 'N15_M07_F10_KI14_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI01.rar']]
# file to exrtract is is::
# ./data/PDB/KI01/raw/KI01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI01_18.mat', 'N15_M07_F10_KI01_19.mat', 'N15_M07_F10_KI01_20.mat', 'N15_M07_F10_KI01_8.mat', 'N15_M07_F10_KI01_9.mat', 'N15_M07_F10_KI01_7.mat', 'N15_M07_F10_KI01_6.mat', 'N15_M07_F10_KI01_4.mat', 'N15_M07_F10_KI01_5.mat', 'N15_M07_F10_KI01_1.mat', 'N15_M07_F10_KI01_2.mat', 'N15_M07_F10_KI01_3.mat', 'N15_M07_F10_KI01_11.mat', 'N15_M07_F10_KI01_10.mat', 'N15_M07_F10_KI01_12.mat', 'N15_M07_F10_KI01_13.mat', 'N15_M07_F10_KI01_17.mat', 'N15_M07_F10_KI01_16.mat', 'N15_M07_F10_KI01_14.mat', 'N15_M07_F10_KI01_15.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI21', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI21.rar']]
# file to exrtract is is::
# ./data/PDB/KI21/raw/KI21.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI21_8.mat', 'N15_M07_F10_KI21_20.mat', 'N15_M07_F10_KI21_9.mat', 'N15_M07_F10_KI21_18.mat', 'N15_M07_F10_KI21_19.mat', 'N15_M07_F10_KI21_2.mat', 'N15_M07_F10_KI21_17.mat', 'N15_M07_F10_KI21_16.mat', 'N15_M07_F10_KI21_3.mat', 'N15_M07_F10_KI21_1.mat', 'N15_M07_F10_KI21_14.mat', 'N15_M07_F10_KI21_15.mat', 'N15_M07_F10_KI21_4.mat', 'N15_M07_F10_KI21_11.mat', 'N15_M07_F10_KI21_10.mat', 'N15_M07_F10_KI21_5.mat', 'N15_M07_F10_KI21_7.mat', 'N15_M07_F10_KI21_12.mat', 'N15_M07_F10_KI21_13.mat', 'N15_M07_F10_KI21_6.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI05.rar']]
# file to exrtract is is::
# ./data/PDB/KI05/raw/KI05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI05_20.mat', 'N15_M07_F10_KI05_9.mat', 'N15_M07_F10_KI05_8.mat', 'N15_M07_F10_KI05_19.mat', 'N15_M07_F10_KI05_18.mat', 'N15_M07_F10_KI05_16.mat', 'N15_M07_F10_KI05_3.mat', 'N15_M07_F10_KI05_2.mat', 'N15_M07_F10_KI05_17.mat', 'N15_M07_F10_KI05_15.mat', 'N15_M07_F10_KI05_1.mat', 'N15_M07_F10_KI05_14.mat', 'N15_M07_F10_KI05_10.mat', 'N15_M07_F10_KI05_5.mat', 'N15_M07_F10_KI05_4.mat', 'N15_M07_F10_KI05_11.mat', 'N15_M07_F10_KI05_13.mat', 'N15_M07_F10_KI05_6.mat', 'N15_M07_F10_KI05_7.mat', 'N15_M07_F10_KI05_12.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI17', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI17.rar']]
# file to exrtract is is::
# ./data/PDB/KI17/raw/KI17.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI17_3.mat', 'N15_M07_F10_KI17_2.mat', 'N15_M07_F10_KI17_1.mat', 'N15_M07_F10_KI17_5.mat', 'N15_M07_F10_KI17_4.mat', 'N15_M07_F10_KI17_6.mat', 'N15_M07_F10_KI17_7.mat', 'N15_M07_F10_KI17_20.mat', 'N15_M07_F10_KI17_19.mat', 'N15_M07_F10_KI17_18.mat', 'N15_M07_F10_KI17_16.mat', 'N15_M07_F10_KI17_17.mat', 'N15_M07_F10_KI17_15.mat', 'N15_M07_F10_KI17_14.mat', 'N15_M07_F10_KI17_10.mat', 'N15_M07_F10_KI17_11.mat', 'N15_M07_F10_KI17_13.mat', 'N15_M07_F10_KI17_12.mat', 'N15_M07_F10_KI17_9.mat', 'N15_M07_F10_KI17_8.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI07.rar']]
# file to exrtract is is::
# ./data/PDB/KI07/raw/KI07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI07_8.mat', 'N15_M07_F10_KI07_9.mat', 'N15_M07_F10_KI07_19.mat', 'N15_M07_F10_KI07_18.mat', 'N15_M07_F10_KI07_20.mat', 'N15_M07_F10_KI07_1.mat', 'N15_M07_F10_KI07_13.mat', 'N15_M07_F10_KI07_12.mat', 'N15_M07_F10_KI07_2.mat', 'N15_M07_F10_KI07_10.mat', 'N15_M07_F10_KI07_11.mat', 'N15_M07_F10_KI07_3.mat', 'N15_M07_F10_KI07_7.mat', 'N15_M07_F10_KI07_15.mat', 'N15_M07_F10_KI07_14.mat', 'N15_M07_F10_KI07_6.mat', 'N15_M07_F10_KI07_4.mat', 'N15_M07_F10_KI07_16.mat', 'N15_M07_F10_KI07_17.mat', 'N15_M07_F10_KI07_5.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI18', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI18.rar']]
# file to exrtract is is::
# ./data/PDB/KI18/raw/KI18.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI18_11.mat', 'N15_M07_F10_KI18_10.mat', 'N15_M07_F10_KI18_12.mat', 'N15_M07_F10_KI18_13.mat', 'N15_M07_F10_KI18_17.mat', 'N15_M07_F10_KI18_16.mat', 'N15_M07_F10_KI18_14.mat', 'N15_M07_F10_KI18_15.mat', 'N15_M07_F10_KI18_9.mat', 'N15_M07_F10_KI18_8.mat', 'N15_M07_F10_KI18_6.mat', 'N15_M07_F10_KI18_7.mat', 'N15_M07_F10_KI18_5.mat', 'N15_M07_F10_KI18_4.mat', 'N15_M07_F10_KI18_1.mat', 'N15_M07_F10_KI18_3.mat', 'N15_M07_F10_KI18_2.mat', 'N15_M07_F10_KI18_18.mat', 'N15_M07_F10_KI18_19.mat', 'N15_M07_F10_KI18_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI16.rar']]
# file to exrtract is is::
# ./data/PDB/KI16/raw/KI16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI16_14.mat', 'N15_M07_F10_KI16_15.mat', 'N15_M07_F10_KI16_17.mat', 'N15_M07_F10_KI16_16.mat', 'N15_M07_F10_KI16_12.mat', 'N15_M07_F10_KI16_13.mat', 'N15_M07_F10_KI16_11.mat', 'N15_M07_F10_KI16_10.mat', 'N15_M07_F10_KI16_1.mat', 'N15_M07_F10_KI16_3.mat', 'N15_M07_F10_KI16_2.mat', 'N15_M07_F10_KI16_6.mat', 'N15_M07_F10_KI16_7.mat', 'N15_M07_F10_KI16_5.mat', 'N15_M07_F10_KI16_4.mat', 'N15_M07_F10_KI16_9.mat', 'N15_M07_F10_KI16_8.mat', 'N15_M07_F10_KI16_20.mat', 'N15_M07_F10_KI16_18.mat', 'N15_M07_F10_KI16_19.mat']
# #####################
#  datacollection and unpack done

# %%
X_train = np.concatenate([d_healthy_train_1.X_train, 
                          d_OR_train_2.X_train,d_OR_train_3.X_train, 
                          d_OR_train_4.X_train,
                          d_IR_train_2.X_train,d_IR_train_3.X_train,
                          d_IR_train_4.X_train])

y_train = np.concatenate([d_healthy_train_1.y_train, 
                          d_OR_train_2.y_train,d_OR_train_3.y_train, 
                          d_OR_train_4.y_train, 
                          d_IR_train_2.y_train,d_IR_train_3.y_train,
                          d_IR_train_4.y_train])

#traning data
print(np.shape(X_train))
print(np.shape(y_train))
# Out:
# (11636, 2560)
# (11636,)

# %%
# any bias ? 
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 1808, 2: 4422, 3: 5406}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, Conv1D, Flatten, Reshape, MaxPooling1D, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import os

#use GPU acceleration
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"


# Defining the convolution layer
def wdcnn(filters, kernerl_size, strides, conv_padding, pool_padding,  pool_size, BatchNormal):
    """wdcnn Layer neuron

    :param filters: Number of convolution kernels, integer
    :param kernerl_size: Convolution kernel size, integer
    :param strides: Step size, integer
    :param conv_padding: 'same','valid'
    :param pool_padding: 'same','valid'
    :param pool_size: Pooled layer core size, integer
    :param BatchNormal: Whether Batchnormal, Boolean
    :return: model
    """
    model.add(Conv1D(filters=filters, kernel_size=kernerl_size, strides=strides,
                     padding=conv_padding, kernel_regularizer=regularizers.l2(1e-4)))
    if BatchNormal:
        model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=pool_size, padding=pool_padding))
    return model


#### from wdcnnn
BatchNorm = True # Whether to batch normalize
classes = 4#(max(d1.y_train)+1)

# Instantiated sequential model
model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1], ), name='x_input'))
model.add(Reshape((int(X_train.shape[1] / 1), 1), input_shape=(X_train.shape[1], )))
# Set up the input layer, the first layer of convolution. Because you want to specify input_shape, it is released separately.#model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling1D(pool_size=2))
# second layer conv
model = wdcnn(filters=32, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid',  pool_size=2, BatchNormal=BatchNorm)
# Third layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fourth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fifth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='valid',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Flatten from convolution to full connection
model.add(Flatten())

# Flatten from convolution to full connection
model.add(Dense(units=100, activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
# Decrease the output layer
#model.add(Dense(units=num_classes, activation='softmax', kernel_regularizer=regularizers.l2(1e-4)))
model.add(Dense(classes, activation='softmax', name='y_pred'))


# this controls the learning rate
opt = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 2560, 1)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 160, 16)           1040
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 160, 16)           64
# _________________________________________________________________
# activation_5 (Activation)    (None, 160, 16)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 160, 32)           1568
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 160, 32)           128
# _________________________________________________________________
# activation_6 (Activation)    (None, 160, 32)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 80, 32)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 80, 64)            6208
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 80, 64)            256
# _________________________________________________________________
# activation_7 (Activation)    (None, 80, 64)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 40, 64)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 40, 64)            12352
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 40, 64)            256
# _________________________________________________________________
# activation_8 (Activation)    (None, 40, 64)            0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 20, 64)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 18, 64)            12352
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 18, 64)            256
# _________________________________________________________________
# activation_9 (Activation)    (None, 18, 64)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 9, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               57700
# _________________________________________________________________
# y_pred (Dense)               (None, 4)                 404
# =================================================================
# Total params: 92,584
# Trainable params: 92,104
# Non-trainable params: 480
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from keras import utils

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.33, random_state=42)

print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train))
print(np.shape(y_test))



y_train_cat = utils.to_categorical(
    y_train,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)

y_test_cat = utils.to_categorical(
    y_test,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)
# Out:
# (7796, 2560)
# (3840, 2560)
# (7796,)
# (3840,)

# %%
history = model.fit(X_train, y_train_cat, batch_size=50, epochs=100, validation_data=(X_test, y_test_cat))
# Out:
# Train on 7796 samples, validate on 3840 samples
# Epoch 1/100
# 7796/7796 [==============================] - 27s 3ms/sample - loss: 0.4366 - accuracy: 0.8148 - val_loss: 2.6983 - val_accuracy: 0.2742
# Epoch 2/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.1831 - accuracy: 0.9341 - val_loss: 3.1790 - val_accuracy: 0.4461
# Epoch 3/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.1391 - accuracy: 0.9587 - val_loss: 0.4828 - val_accuracy: 0.8495
# Epoch 4/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0966 - accuracy: 0.9743 - val_loss: 1.6455 - val_accuracy: 0.7305
# Epoch 5/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.1036 - accuracy: 0.9752 - val_loss: 0.3883 - val_accuracy: 0.8865
# Epoch 6/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0713 - accuracy: 0.9863 - val_loss: 0.1307 - val_accuracy: 0.9602
# Epoch 7/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0730 - accuracy: 0.9845 - val_loss: 0.8210 - val_accuracy: 0.8471
# Epoch 8/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0594 - accuracy: 0.9904 - val_loss: 0.5964 - val_accuracy: 0.8625
# Epoch 9/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0672 - accuracy: 0.9878 - val_loss: 0.5009 - val_accuracy: 0.8828
# Epoch 10/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0497 - accuracy: 0.9941 - val_loss: 0.8082 - val_accuracy: 0.8422
# Epoch 11/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0545 - accuracy: 0.9917 - val_loss: 0.3732 - val_accuracy: 0.9135
# Epoch 12/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0531 - accuracy: 0.9924 - val_loss: 0.3517 - val_accuracy: 0.9089
# Epoch 13/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0552 - accuracy: 0.9910 - val_loss: 0.2668 - val_accuracy: 0.9326
# Epoch 14/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0585 - accuracy: 0.9909 - val_loss: 0.1423 - val_accuracy: 0.9667
# Epoch 15/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0546 - accuracy: 0.9914 - val_loss: 0.9050 - val_accuracy: 0.8391
# Epoch 16/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0392 - accuracy: 0.9982 - val_loss: 0.5442 - val_accuracy: 0.8953
# Epoch 17/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0468 - accuracy: 0.9941 - val_loss: 0.3471 - val_accuracy: 0.9164
# Epoch 18/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0444 - accuracy: 0.9949 - val_loss: 0.2833 - val_accuracy: 0.9349
# Epoch 19/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0553 - accuracy: 0.9911 - val_loss: 0.7547 - val_accuracy: 0.8409
# Epoch 20/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0415 - accuracy: 0.9954 - val_loss: 0.6869 - val_accuracy: 0.8760
# Epoch 21/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0476 - accuracy: 0.9938 - val_loss: 1.6087 - val_accuracy: 0.8143
# Epoch 22/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0387 - accuracy: 0.9963 - val_loss: 0.1399 - val_accuracy: 0.9643
# Epoch 23/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0391 - accuracy: 0.9962 - val_loss: 0.2659 - val_accuracy: 0.9396
# Epoch 24/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0431 - accuracy: 0.9945 - val_loss: 0.3839 - val_accuracy: 0.9177
# Epoch 25/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0343 - accuracy: 0.9979 - val_loss: 0.4776 - val_accuracy: 0.9133
# Epoch 26/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0310 - accuracy: 0.9988 - val_loss: 0.2490 - val_accuracy: 0.9443
# Epoch 27/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0454 - accuracy: 0.9929 - val_loss: 1.7156 - val_accuracy: 0.7492
# Epoch 28/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0489 - accuracy: 0.9917 - val_loss: 1.5810 - val_accuracy: 0.7583
# Epoch 29/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0370 - accuracy: 0.9965 - val_loss: 0.2037 - val_accuracy: 0.9568
# Epoch 30/100
# 7796/7796 [==============================] - 25s 3ms/sample - loss: 0.0450 - accuracy: 0.9941 - val_loss: 0.2106 - val_accuracy: 0.9490
# Epoch 31/100
# 7796/7796 [==============================] - 24s 3ms/sample - loss: 0.0352 - accuracy: 0.9977 - val_loss: 0.1569 - val_accuracy: 0.9654
# Epoch 32/100
# 7796/7796 [==============================] - 27s 3ms/sample - loss: 0.0418 - accuracy: 0.9949 - val_loss: 1.0201 - val_accuracy: 0.8271
# Epoch 33/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0446 - accuracy: 0.9940 - val_loss: 0.8030 - val_accuracy: 0.8763
# Epoch 34/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0312 - accuracy: 0.9992 - val_loss: 0.3079 - val_accuracy: 0.9357
# Epoch 35/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0444 - accuracy: 0.9928 - val_loss: 0.8284 - val_accuracy: 0.8396
# Epoch 36/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0321 - accuracy: 0.9983 - val_loss: 0.7053 - val_accuracy: 0.8938
# Epoch 37/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0328 - accuracy: 0.9981 - val_loss: 0.7175 - val_accuracy: 0.8672
# Epoch 38/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0337 - accuracy: 0.9969 - val_loss: 0.6927 - val_accuracy: 0.8930
# Epoch 39/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0405 - accuracy: 0.9955 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 40/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0529 - accuracy: 0.9909 - val_loss: 0.1311 - val_accuracy: 0.9688
# Epoch 41/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0468 - accuracy: 0.9928 - val_loss: 2.7233 - val_accuracy: 0.7721
# Epoch 42/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0348 - accuracy: 0.9974 - val_loss: 0.7284 - val_accuracy: 0.8625
# Epoch 43/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0302 - accuracy: 0.9986 - val_loss: 0.1728 - val_accuracy: 0.9591
# Epoch 44/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0363 - accuracy: 0.9969 - val_loss: 0.2329 - val_accuracy: 0.9435
# Epoch 45/100
# 7796/7796 [==============================] - 25s 3ms/sample - loss: 0.0314 - accuracy: 0.9978 - val_loss: 0.7724 - val_accuracy: 0.8815
# Epoch 46/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0319 - accuracy: 0.9974 - val_loss: 0.1502 - val_accuracy: 0.9682
# Epoch 47/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0336 - accuracy: 0.9967 - val_loss: 0.2003 - val_accuracy: 0.9557
# Epoch 48/100
# 7796/7796 [==============================] - 18s 2ms/sample - loss: 0.0352 - accuracy: 0.9960 - val_loss: 0.1741 - val_accuracy: 0.9620
# Epoch 49/100
# 7796/7796 [==============================] - 18s 2ms/sample - loss: 0.0349 - accuracy: 0.9965 - val_loss: 0.4992 - val_accuracy: 0.9065
# Epoch 50/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0349 - accuracy: 0.9967 - val_loss: 0.3166 - val_accuracy: 0.9331
# Epoch 51/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0317 - accuracy: 0.9979 - val_loss: 0.6671 - val_accuracy: 0.8685
# Epoch 52/100
# 7796/7796 [==============================] - 25s 3ms/sample - loss: 0.0310 - accuracy: 0.9978 - val_loss: 0.1632 - val_accuracy: 0.9656
# Epoch 53/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0368 - accuracy: 0.9960 - val_loss: 0.5526 - val_accuracy: 0.8687
# Epoch 54/100
# 7796/7796 [==============================] - 24s 3ms/sample - loss: 0.0320 - accuracy: 0.9977 - val_loss: 0.1764 - val_accuracy: 0.9638
# Epoch 55/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0268 - accuracy: 0.9988 - val_loss: 0.5128 - val_accuracy: 0.9096
# Epoch 56/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0339 - accuracy: 0.9964 - val_loss: 0.7245 - val_accuracy: 0.8760
# Epoch 57/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0307 - accuracy: 0.9969 - val_loss: 0.4022 - val_accuracy: 0.9263
# Epoch 58/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0309 - accuracy: 0.9977 - val_loss: 1.3738 - val_accuracy: 0.8318
# Epoch 59/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0308 - accuracy: 0.9976 - val_loss: 0.3686 - val_accuracy: 0.9281
# Epoch 60/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0328 - accuracy: 0.9972 - val_loss: 1.3530 - val_accuracy: 0.8477
# Epoch 61/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0321 - accuracy: 0.9967 - val_loss: 0.1398 - val_accuracy: 0.9690
# Epoch 62/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0503 - accuracy: 0.9919 - val_loss: 2.7077 - val_accuracy: 0.7409
# Epoch 63/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0331 - accuracy: 0.9969 - val_loss: 0.1526 - val_accuracy: 0.9612
# Epoch 64/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0360 - accuracy: 0.9949 - val_loss: 0.1197 - val_accuracy: 0.9680
# Epoch 65/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0270 - accuracy: 0.9991 - val_loss: 0.1077 - val_accuracy: 0.9737
# Epoch 66/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0259 - accuracy: 0.9991 - val_loss: 0.1273 - val_accuracy: 0.9708
# Epoch 67/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0276 - accuracy: 0.9988 - val_loss: 0.1318 - val_accuracy: 0.9690
# Epoch 68/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0292 - accuracy: 0.9982 - val_loss: 0.1855 - val_accuracy: 0.9521
# Epoch 69/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0323 - accuracy: 0.9964 - val_loss: 0.2838 - val_accuracy: 0.9383
# Epoch 70/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0277 - accuracy: 0.9985 - val_loss: 0.1534 - val_accuracy: 0.9654
# Epoch 71/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0283 - accuracy: 0.9979 - val_loss: 0.3721 - val_accuracy: 0.9323
# Epoch 72/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0302 - accuracy: 0.9969 - val_loss: 0.8667 - val_accuracy: 0.8794
# Epoch 73/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0260 - accuracy: 0.9992 - val_loss: 0.2246 - val_accuracy: 0.9503
# Epoch 74/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0267 - accuracy: 0.9983 - val_loss: 0.1743 - val_accuracy: 0.9633
# Epoch 75/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0315 - accuracy: 0.9965 - val_loss: 0.1689 - val_accuracy: 0.9586
# Epoch 76/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0265 - accuracy: 0.9987 - val_loss: 0.2539 - val_accuracy: 0.9479
# Epoch 77/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0369 - accuracy: 0.9951 - val_loss: 0.1606 - val_accuracy: 0.9599
# Epoch 78/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0302 - accuracy: 0.9969 - val_loss: 0.2456 - val_accuracy: 0.9471
# Epoch 79/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0301 - accuracy: 0.9973 - val_loss: 0.2684 - val_accuracy: 0.9372
# Epoch 80/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0304 - accuracy: 0.9970 - val_loss: 0.1560 - val_accuracy: 0.9633
# Epoch 81/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0254 - accuracy: 0.9992 - val_loss: 0.8772 - val_accuracy: 0.8565
# Epoch 82/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0404 - accuracy: 0.9946 - val_loss: 0.4234 - val_accuracy: 0.9102
# Epoch 83/100
# 7796/7796 [==============================] - 24s 3ms/sample - loss: 0.0259 - accuracy: 0.9990 - val_loss: 0.1201 - val_accuracy: 0.9664
# Epoch 84/100
# 7796/7796 [==============================] - 24s 3ms/sample - loss: 0.0246 - accuracy: 0.9990 - val_loss: 0.2592 - val_accuracy: 0.9438
# Epoch 85/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0246 - accuracy: 0.9991 - val_loss: 0.1546 - val_accuracy: 0.9628
# Epoch 86/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0241 - accuracy: 0.9988 - val_loss: 0.2062 - val_accuracy: 0.9474
# Epoch 87/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0217 - accuracy: 0.9997 - val_loss: 0.4828 - val_accuracy: 0.9198
# Epoch 88/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0357 - accuracy: 0.9953 - val_loss: 0.2009 - val_accuracy: 0.9484
# Epoch 89/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0350 - accuracy: 0.9956 - val_loss: 0.1866 - val_accuracy: 0.9534
# Epoch 90/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0273 - accuracy: 0.9976 - val_loss: 0.2874 - val_accuracy: 0.9289
# Epoch 91/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0244 - accuracy: 0.9987 - val_loss: 0.2225 - val_accuracy: 0.9479
# Epoch 92/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0235 - accuracy: 0.9991 - val_loss: 0.5445 - val_accuracy: 0.8969
# Epoch 93/100
# 7796/7796 [==============================] - 24s 3ms/sample - loss: 0.0299 - accuracy: 0.9968 - val_loss: 0.1233 - val_accuracy: 0.9701
# Epoch 94/100
# 7796/7796 [==============================] - 23s 3ms/sample - loss: 0.0278 - accuracy: 0.9976 - val_loss: 0.1072 - val_accuracy: 0.9737
# Epoch 95/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0334 - accuracy: 0.9953 - val_loss: 0.5541 - val_accuracy: 0.9044
# Epoch 96/100
# 7796/7796 [==============================] - 20s 3ms/sample - loss: 0.0369 - accuracy: 0.9944 - val_loss: 0.6576 - val_accuracy: 0.8656
# Epoch 97/100
# 7796/7796 [==============================] - 21s 3ms/sample - loss: 0.0261 - accuracy: 0.9985 - val_loss: 0.1020 - val_accuracy: 0.9768
# Epoch 98/100
# 7796/7796 [==============================] - 22s 3ms/sample - loss: 0.0296 - accuracy: 0.9970 - val_loss: 0.2122 - val_accuracy: 0.9505
# Epoch 99/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0243 - accuracy: 0.9991 - val_loss: 0.0985 - val_accuracy: 0.9779
# Epoch 100/100
# 7796/7796 [==============================] - 19s 2ms/sample - loss: 0.0226 - accuracy: 0.9996 - val_loss: 0.0911 - val_accuracy: 0.9812

# %%
#X_test
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, y_test_cat, batch_size=128)
#results = model.evaluate(X_test, Y_test, batch_size=50)
print('test loss, test acc:', results)
# Out:
# # Evaluate on test data
# 3840/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test loss, test acc: [0.09110386756559213, 0.98125]

# %% [markdown]
# 686us/sample - loss: 0.0629 - accuracy: 0.9812
# test loss, test acc: [0.09110386756559213, 0.98125]

# %%
# import for showing the confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

results = model.predict(X_test, 128)# batch_size=HParams.test_batch_size)

# convert from class probabilities to actual class predictions
predicted_classes = np.argmax(results, axis=1)

# Names of predicted classes
class_names = [ "OK", "Outer", "Inner", "Combined"]
#Labels 1 = healthy bearing, 2 = outer ring damage , 3 = inner ring damage, 4 = combined damage


# Generate the confusion matrix
cnf_matrix = confusion_matrix(y_test, predicted_classes)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 579    0   34]
#  [   0 1479    0]
#  [  38    0 1710]]

# %% [markdown]
# ### Conclusion on the results
# The above model was trained with a larger size first input layer of 2560, and accordingly shape of the first input layer <br>
# This corresponds to exactly 1/1 of a full resolution when sampling at 64KHz, and therefore inne ring damages are seen more as distinct, since the damage will not roll through the load zone every time.<br>
# The minor error  may suggest ???
#
# This model was build with :
# * Total params: 92,584
# * Trainable params: 92,104
# * Non-trainable params: 480
#
# And a result of :
#     **686us/sample - loss: 0.0629 - accuracy: 0.9812
#     test loss, test acc: [0.09110386756559213, 0.98125]**

# %% [markdown]
# Use model.load(), to avoid retraining

# %%
model.save('model_2_inputw2560.h5')

# %% [markdown]
# ## Evaluate model, with wider input layer, actual fault data
# Now redo with a full revolution of samples, as input shape<br>
# Instead og using artifically generated data, data from the **HALT tests** are used
# * Total params: 92,584
# * Trainable params: 92,104
# * Non-trainable params: 480

# %%
SliceLen = SamplePerRotation
#healthy sets
d_healthy_train_1 = PDB('K002','1500','1000','700',SliceLen)
d_healthy_test_1  = PDB('K001','1500','1000','700',SliceLen)

#outerring
d_OR_test_1  = PDB('KA22','1500','1000','700',SliceLen)
d_OR_train_2 = PDB('KA01','1500','1000','700',SliceLen)
d_OR_test_2  = PDB('K004','1500','1000','700',SliceLen)
d_OR_train_3 = PDB('KA05','1500','1000','700',SliceLen)
d_OR_test_3  = PDB('KA15','1500','1000','700',SliceLen)
d_OR_train_4 = PDB('KA07','1500','1000','700',SliceLen)
d_OR_test_4  = PDB('KA30','1500','1000','700',SliceLen)
d_OR_test_5  = PDB('KA16','1500','1000','700',SliceLen)

#innerring
d_IR_test_1  = PDB('KI14','1500','1000','700',SliceLen)
d_IR_train_2 = PDB('KI01','1500','1000','700',SliceLen)
d_IR_test_2  = PDB('KI21','1500','1000','700',SliceLen)
d_IR_train_3 = PDB('KI05','1500','1000','700',SliceLen)
d_IR_test_3  = PDB('KI17','1500','1000','700',SliceLen)
d_IR_train_4 = PDB('KI07','1500','1000','700',SliceLen)
d_IR_test_4  = PDB('KI18','1500','1000','700',SliceLen)
d_IR_test_5  = PDB('KI16','1500','1000','700',SliceLen)


print("##################### \n datacollection and unpack done")
# Out:
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K002', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K002.rar']]
# file to exrtract is is::
# ./data/PDB/K002/raw/K002.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K002_12.mat', 'N15_M07_F10_K002_13.mat', 'N15_M07_F10_K002_11.mat', 'N15_M07_F10_K002_10.mat', 'N15_M07_F10_K002_14.mat', 'N15_M07_F10_K002_15.mat', 'N15_M07_F10_K002_17.mat', 'N15_M07_F10_K002_8.mat', 'N15_M07_F10_K002_9.mat', 'N15_M07_F10_K002_16.mat', 'N15_M07_F10_K002_4.mat', 'N15_M07_F10_K002_5.mat', 'N15_M07_F10_K002_18.mat', 'N15_M07_F10_K002_7.mat', 'N15_M07_F10_K002_6.mat', 'N15_M07_F10_K002_19.mat', 'N15_M07_F10_K002_2.mat', 'N15_M07_F10_K002_3.mat', 'N15_M07_F10_K002_20.mat', 'N15_M07_F10_K002_1.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K001', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K001.rar']]
# file to exrtract is is::
# ./data/PDB/K001/raw/K001.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K001_20.mat', 'N15_M07_F10_K001_19.mat', 'N15_M07_F10_K001_9.mat', 'N15_M07_F10_K001_8.mat', 'N15_M07_F10_K001_18.mat', 'N15_M07_F10_K001_15.mat', 'N15_M07_F10_K001_5.mat', 'N15_M07_F10_K001_4.mat', 'N15_M07_F10_K001_14.mat', 'N15_M07_F10_K001_16.mat', 'N15_M07_F10_K001_6.mat', 'N15_M07_F10_K001_7.mat', 'N15_M07_F10_K001_17.mat', 'N15_M07_F10_K001_3.mat', 'N15_M07_F10_K001_13.mat', 'N15_M07_F10_K001_12.mat', 'N15_M07_F10_K001_2.mat', 'N15_M07_F10_K001_10.mat', 'N15_M07_F10_K001_11.mat', 'N15_M07_F10_K001_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA22', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA22.rar']]
# file to exrtract is is::
# ./data/PDB/KA22/raw/KA22.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA22_9.mat', 'N15_M07_F10_KA22_8.mat', 'N15_M07_F10_KA22_20.mat', 'N15_M07_F10_KA22_19.mat', 'N15_M07_F10_KA22_18.mat', 'N15_M07_F10_KA22_16.mat', 'N15_M07_F10_KA22_17.mat', 'N15_M07_F10_KA22_15.mat', 'N15_M07_F10_KA22_14.mat', 'N15_M07_F10_KA22_10.mat', 'N15_M07_F10_KA22_11.mat', 'N15_M07_F10_KA22_13.mat', 'N15_M07_F10_KA22_12.mat', 'N15_M07_F10_KA22_5.mat', 'N15_M07_F10_KA22_4.mat', 'N15_M07_F10_KA22_6.mat', 'N15_M07_F10_KA22_7.mat', 'N15_M07_F10_KA22_3.mat', 'N15_M07_F10_KA22_2.mat', 'N15_M07_F10_KA22_1.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA01.rar']]
# file to exrtract is is::
# ./data/PDB/KA01/raw/KA01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA01_8.mat', 'N15_M07_F10_KA01_17.mat', 'N15_M07_F10_KA01_16.mat', 'N15_M07_F10_KA01_9.mat', 'N15_M07_F10_KA01_14.mat', 'N15_M07_F10_KA01_15.mat', 'N15_M07_F10_KA01_11.mat', 'N15_M07_F10_KA01_10.mat', 'N15_M07_F10_KA01_12.mat', 'N15_M07_F10_KA01_13.mat', 'N15_M07_F10_KA01_1.mat', 'N15_M07_F10_KA01_2.mat', 'N15_M07_F10_KA01_20.mat', 'N15_M07_F10_KA01_3.mat', 'N15_M07_F10_KA01_7.mat', 'N15_M07_F10_KA01_18.mat', 'N15_M07_F10_KA01_19.mat', 'N15_M07_F10_KA01_6.mat', 'N15_M07_F10_KA01_4.mat', 'N15_M07_F10_KA01_5.mat']
# Y is:
# 1
# filestring
# N15_M07_F10_
# l:
# [['K004', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/K004.rar']]
# file to exrtract is is::
# ./data/PDB/K004/raw/K004.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_K004_8.mat', 'N15_M07_F10_K004_9.mat', 'N15_M07_F10_K004_10.mat', 'N15_M07_F10_K004_11.mat', 'N15_M07_F10_K004_13.mat', 'N15_M07_F10_K004_12.mat', 'N15_M07_F10_K004_16.mat', 'N15_M07_F10_K004_17.mat', 'N15_M07_F10_K004_15.mat', 'N15_M07_F10_K004_14.mat', 'N15_M07_F10_K004_19.mat', 'N15_M07_F10_K004_18.mat', 'N15_M07_F10_K004_20.mat', 'N15_M07_F10_K004_2.mat', 'N15_M07_F10_K004_3.mat', 'N15_M07_F10_K004_1.mat', 'N15_M07_F10_K004_4.mat', 'N15_M07_F10_K004_5.mat', 'N15_M07_F10_K004_7.mat', 'N15_M07_F10_K004_6.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA05.rar']]
# file to exrtract is is::
# ./data/PDB/KA05/raw/KA05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA05_10.mat', 'N15_M07_F10_KA05_11.mat', 'N15_M07_F10_KA05_13.mat', 'N15_M07_F10_KA05_12.mat', 'N15_M07_F10_KA05_16.mat', 'N15_M07_F10_KA05_17.mat', 'N15_M07_F10_KA05_15.mat', 'N15_M07_F10_KA05_14.mat', 'N15_M07_F10_KA05_9.mat', 'N15_M07_F10_KA05_8.mat', 'N15_M07_F10_KA05_5.mat', 'N15_M07_F10_KA05_4.mat', 'N15_M07_F10_KA05_6.mat', 'N15_M07_F10_KA05_7.mat', 'N15_M07_F10_KA05_3.mat', 'N15_M07_F10_KA05_2.mat', 'N15_M07_F10_KA05_1.mat', 'N15_M07_F10_KA05_19.mat', 'N15_M07_F10_KA05_18.mat', 'N15_M07_F10_KA05_20.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA15', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA15.rar']]
# file to exrtract is is::
# ./data/PDB/KA15/raw/KA15.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA15_7.mat', 'N15_M07_F10_KA15_15.mat', 'N15_M07_F10_KA15_14.mat', 'N15_M07_F10_KA15_6.mat', 'N15_M07_F10_KA15_4.mat', 'N15_M07_F10_KA15_16.mat', 'N15_M07_F10_KA15_17.mat', 'N15_M07_F10_KA15_5.mat', 'N15_M07_F10_KA15_1.mat', 'N15_M07_F10_KA15_13.mat', 'N15_M07_F10_KA15_12.mat', 'N15_M07_F10_KA15_2.mat', 'N15_M07_F10_KA15_10.mat', 'N15_M07_F10_KA15_11.mat', 'N15_M07_F10_KA15_3.mat', 'N15_M07_F10_KA15_20.mat', 'N15_M07_F10_KA15_8.mat', 'N15_M07_F10_KA15_9.mat', 'N15_M07_F10_KA15_19.mat', 'N15_M07_F10_KA15_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA07.rar']]
# file to exrtract is is::
# ./data/PDB/KA07/raw/KA07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA07_15.mat', 'N15_M07_F10_KA07_14.mat', 'N15_M07_F10_KA07_16.mat', 'N15_M07_F10_KA07_17.mat', 'N15_M07_F10_KA07_13.mat', 'N15_M07_F10_KA07_12.mat', 'N15_M07_F10_KA07_10.mat', 'N15_M07_F10_KA07_11.mat', 'N15_M07_F10_KA07_8.mat', 'N15_M07_F10_KA07_9.mat', 'N15_M07_F10_KA07_7.mat', 'N15_M07_F10_KA07_6.mat', 'N15_M07_F10_KA07_4.mat', 'N15_M07_F10_KA07_5.mat', 'N15_M07_F10_KA07_1.mat', 'N15_M07_F10_KA07_2.mat', 'N15_M07_F10_KA07_3.mat', 'N15_M07_F10_KA07_20.mat', 'N15_M07_F10_KA07_19.mat', 'N15_M07_F10_KA07_18.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA30', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA30.rar']]
# file to exrtract is is::
# ./data/PDB/KA30/raw/KA30.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA30_5.mat', 'N15_M07_F10_KA30_4.mat', 'N15_M07_F10_KA30_6.mat', 'N15_M07_F10_KA30_20.mat', 'N15_M07_F10_KA30_7.mat', 'N15_M07_F10_KA30_3.mat', 'N15_M07_F10_KA30_19.mat', 'N15_M07_F10_KA30_18.mat', 'N15_M07_F10_KA30_2.mat', 'N15_M07_F10_KA30_1.mat', 'N15_M07_F10_KA30_16.mat', 'N15_M07_F10_KA30_17.mat', 'N15_M07_F10_KA30_15.mat', 'N15_M07_F10_KA30_14.mat', 'N15_M07_F10_KA30_10.mat', 'N15_M07_F10_KA30_11.mat', 'N15_M07_F10_KA30_9.mat', 'N15_M07_F10_KA30_13.mat', 'N15_M07_F10_KA30_12.mat', 'N15_M07_F10_KA30_8.mat']
# Y is:
# 2
# filestring
# N15_M07_F10_
# l:
# [['KA16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KA16.rar']]
# file to exrtract is is::
# ./data/PDB/KA16/raw/KA16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KA16_6.mat', 'N15_M07_F10_KA16_7.mat', 'N15_M07_F10_KA16_18.mat', 'N15_M07_F10_KA16_5.mat', 'N15_M07_F10_KA16_4.mat', 'N15_M07_F10_KA16_19.mat', 'N15_M07_F10_KA16_1.mat', 'N15_M07_F10_KA16_20.mat', 'N15_M07_F10_KA16_3.mat', 'N15_M07_F10_KA16_2.mat', 'N15_M07_F10_KA16_12.mat', 'N15_M07_F10_KA16_13.mat', 'N15_M07_F10_KA16_11.mat', 'N15_M07_F10_KA16_10.mat', 'N15_M07_F10_KA16_14.mat', 'N15_M07_F10_KA16_9.mat', 'N15_M07_F10_KA16_8.mat', 'N15_M07_F10_KA16_15.mat', 'N15_M07_F10_KA16_17.mat', 'N15_M07_F10_KA16_16.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI14', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI14.rar']]
# file to exrtract is is::
# ./data/PDB/KI14/raw/KI14.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI14_11.mat', 'N15_M07_F10_KI14_10.mat', 'N15_M07_F10_KI14_12.mat', 'N15_M07_F10_KI14_13.mat', 'N15_M07_F10_KI14_17.mat', 'N15_M07_F10_KI14_16.mat', 'N15_M07_F10_KI14_14.mat', 'N15_M07_F10_KI14_15.mat', 'N15_M07_F10_KI14_2.mat', 'N15_M07_F10_KI14_3.mat', 'N15_M07_F10_KI14_1.mat', 'N15_M07_F10_KI14_4.mat', 'N15_M07_F10_KI14_5.mat', 'N15_M07_F10_KI14_7.mat', 'N15_M07_F10_KI14_6.mat', 'N15_M07_F10_KI14_8.mat', 'N15_M07_F10_KI14_9.mat', 'N15_M07_F10_KI14_18.mat', 'N15_M07_F10_KI14_19.mat', 'N15_M07_F10_KI14_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI01', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI01.rar']]
# file to exrtract is is::
# ./data/PDB/KI01/raw/KI01.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI01_18.mat', 'N15_M07_F10_KI01_19.mat', 'N15_M07_F10_KI01_20.mat', 'N15_M07_F10_KI01_8.mat', 'N15_M07_F10_KI01_9.mat', 'N15_M07_F10_KI01_7.mat', 'N15_M07_F10_KI01_6.mat', 'N15_M07_F10_KI01_4.mat', 'N15_M07_F10_KI01_5.mat', 'N15_M07_F10_KI01_1.mat', 'N15_M07_F10_KI01_2.mat', 'N15_M07_F10_KI01_3.mat', 'N15_M07_F10_KI01_11.mat', 'N15_M07_F10_KI01_10.mat', 'N15_M07_F10_KI01_12.mat', 'N15_M07_F10_KI01_13.mat', 'N15_M07_F10_KI01_17.mat', 'N15_M07_F10_KI01_16.mat', 'N15_M07_F10_KI01_14.mat', 'N15_M07_F10_KI01_15.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI21', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI21.rar']]
# file to exrtract is is::
# ./data/PDB/KI21/raw/KI21.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI21_8.mat', 'N15_M07_F10_KI21_20.mat', 'N15_M07_F10_KI21_9.mat', 'N15_M07_F10_KI21_18.mat', 'N15_M07_F10_KI21_19.mat', 'N15_M07_F10_KI21_2.mat', 'N15_M07_F10_KI21_17.mat', 'N15_M07_F10_KI21_16.mat', 'N15_M07_F10_KI21_3.mat', 'N15_M07_F10_KI21_1.mat', 'N15_M07_F10_KI21_14.mat', 'N15_M07_F10_KI21_15.mat', 'N15_M07_F10_KI21_4.mat', 'N15_M07_F10_KI21_11.mat', 'N15_M07_F10_KI21_10.mat', 'N15_M07_F10_KI21_5.mat', 'N15_M07_F10_KI21_7.mat', 'N15_M07_F10_KI21_12.mat', 'N15_M07_F10_KI21_13.mat', 'N15_M07_F10_KI21_6.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI05', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI05.rar']]
# file to exrtract is is::
# ./data/PDB/KI05/raw/KI05.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI05_20.mat', 'N15_M07_F10_KI05_9.mat', 'N15_M07_F10_KI05_8.mat', 'N15_M07_F10_KI05_19.mat', 'N15_M07_F10_KI05_18.mat', 'N15_M07_F10_KI05_16.mat', 'N15_M07_F10_KI05_3.mat', 'N15_M07_F10_KI05_2.mat', 'N15_M07_F10_KI05_17.mat', 'N15_M07_F10_KI05_15.mat', 'N15_M07_F10_KI05_1.mat', 'N15_M07_F10_KI05_14.mat', 'N15_M07_F10_KI05_10.mat', 'N15_M07_F10_KI05_5.mat', 'N15_M07_F10_KI05_4.mat', 'N15_M07_F10_KI05_11.mat', 'N15_M07_F10_KI05_13.mat', 'N15_M07_F10_KI05_6.mat', 'N15_M07_F10_KI05_7.mat', 'N15_M07_F10_KI05_12.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI17', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI17.rar']]
# file to exrtract is is::
# ./data/PDB/KI17/raw/KI17.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI17_3.mat', 'N15_M07_F10_KI17_2.mat', 'N15_M07_F10_KI17_1.mat', 'N15_M07_F10_KI17_5.mat', 'N15_M07_F10_KI17_4.mat', 'N15_M07_F10_KI17_6.mat', 'N15_M07_F10_KI17_7.mat', 'N15_M07_F10_KI17_20.mat', 'N15_M07_F10_KI17_19.mat', 'N15_M07_F10_KI17_18.mat', 'N15_M07_F10_KI17_16.mat', 'N15_M07_F10_KI17_17.mat', 'N15_M07_F10_KI17_15.mat', 'N15_M07_F10_KI17_14.mat', 'N15_M07_F10_KI17_10.mat', 'N15_M07_F10_KI17_11.mat', 'N15_M07_F10_KI17_13.mat', 'N15_M07_F10_KI17_12.mat', 'N15_M07_F10_KI17_9.mat', 'N15_M07_F10_KI17_8.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI07', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI07.rar']]
# file to exrtract is is::
# ./data/PDB/KI07/raw/KI07.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI07_8.mat', 'N15_M07_F10_KI07_9.mat', 'N15_M07_F10_KI07_19.mat', 'N15_M07_F10_KI07_18.mat', 'N15_M07_F10_KI07_20.mat', 'N15_M07_F10_KI07_1.mat', 'N15_M07_F10_KI07_13.mat', 'N15_M07_F10_KI07_12.mat', 'N15_M07_F10_KI07_2.mat', 'N15_M07_F10_KI07_10.mat', 'N15_M07_F10_KI07_11.mat', 'N15_M07_F10_KI07_3.mat', 'N15_M07_F10_KI07_7.mat', 'N15_M07_F10_KI07_15.mat', 'N15_M07_F10_KI07_14.mat', 'N15_M07_F10_KI07_6.mat', 'N15_M07_F10_KI07_4.mat', 'N15_M07_F10_KI07_16.mat', 'N15_M07_F10_KI07_17.mat', 'N15_M07_F10_KI07_5.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI18', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI18.rar']]
# file to exrtract is is::
# ./data/PDB/KI18/raw/KI18.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI18_11.mat', 'N15_M07_F10_KI18_10.mat', 'N15_M07_F10_KI18_12.mat', 'N15_M07_F10_KI18_13.mat', 'N15_M07_F10_KI18_17.mat', 'N15_M07_F10_KI18_16.mat', 'N15_M07_F10_KI18_14.mat', 'N15_M07_F10_KI18_15.mat', 'N15_M07_F10_KI18_9.mat', 'N15_M07_F10_KI18_8.mat', 'N15_M07_F10_KI18_6.mat', 'N15_M07_F10_KI18_7.mat', 'N15_M07_F10_KI18_5.mat', 'N15_M07_F10_KI18_4.mat', 'N15_M07_F10_KI18_1.mat', 'N15_M07_F10_KI18_3.mat', 'N15_M07_F10_KI18_2.mat', 'N15_M07_F10_KI18_18.mat', 'N15_M07_F10_KI18_19.mat', 'N15_M07_F10_KI18_20.mat']
# Y is:
# 3
# filestring
# N15_M07_F10_
# l:
# [['KI16', '1500', '400', 'http://groups.uni-paderborn.de/kat/BearingDataCenter/KI16.rar']]
# file to exrtract is is::
# ./data/PDB/KI16/raw/KI16.rar
# file already extracted, skipping unrar
# sorted filelist:
# ['N15_M07_F10_KI16_14.mat', 'N15_M07_F10_KI16_15.mat', 'N15_M07_F10_KI16_17.mat', 'N15_M07_F10_KI16_16.mat', 'N15_M07_F10_KI16_12.mat', 'N15_M07_F10_KI16_13.mat', 'N15_M07_F10_KI16_11.mat', 'N15_M07_F10_KI16_10.mat', 'N15_M07_F10_KI16_1.mat', 'N15_M07_F10_KI16_3.mat', 'N15_M07_F10_KI16_2.mat', 'N15_M07_F10_KI16_6.mat', 'N15_M07_F10_KI16_7.mat', 'N15_M07_F10_KI16_5.mat', 'N15_M07_F10_KI16_4.mat', 'N15_M07_F10_KI16_9.mat', 'N15_M07_F10_KI16_8.mat', 'N15_M07_F10_KI16_20.mat', 'N15_M07_F10_KI16_18.mat', 'N15_M07_F10_KI16_19.mat']
# #####################
#  datacollection and unpack done

# %%
#test data, NOTE from the PDB class, when using to generate data, not split by test/training, 
#all data is to be read from "class.<X/y>.train"
X_train_actual = np.concatenate([d_healthy_test_1.X_train, 
                          d_OR_test_2.X_train,d_OR_test_3.X_train, 
                          d_OR_test_4.X_train,
                          d_IR_test_2.X_train,d_IR_test_3.X_train,
                          d_IR_test_4.X_train])

y_train_actual = np.concatenate([d_healthy_test_1.y_train, 
                          d_OR_test_2.y_train,d_OR_test_3.y_train, 
                          d_OR_test_4.y_train, 
                          d_IR_test_2.y_train,d_IR_test_3.y_train,
                          d_IR_test_4.y_train])
#testing data
print(np.shape(X_train_actual))
print(np.shape(y_train_actual))
# Out:
# (11801, 2560)
# (11801,)

# %%
# any bias ? 
unique, counts = np.unique(y_train_actual, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 3600, 2: 3598, 3: 4603}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, Conv1D, Flatten, Reshape, MaxPooling1D, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import os

#use GPU acceleration
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"


# Defining the convolution layer
def wdcnn(filters, kernerl_size, strides, conv_padding, pool_padding,  pool_size, BatchNormal):
    """wdcnn Layer neuron

    :param filters: Number of convolution kernels, integer
    :param kernerl_size: Convolution kernel size, integer
    :param strides: Step size, integer
    :param conv_padding: 'same','valid'
    :param pool_padding: 'same','valid'
    :param pool_size: Pooled layer core size, integer
    :param BatchNormal: Whether Batchnormal, Boolean
    :return: model
    """
    model.add(Conv1D(filters=filters, kernel_size=kernerl_size, strides=strides,
                     padding=conv_padding, kernel_regularizer=regularizers.l2(1e-4)))
    if BatchNormal:
        model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=pool_size, padding=pool_padding))
    return model


#### from wdcnnn
BatchNorm = True # Whether to batch normalize
classes = 4#(max(d1.y_train)+1)

# Instantiated sequential model
model = Sequential()
model.add(InputLayer(input_shape=(X_train_actual.shape[1], ), name='x_input'))
model.add(Reshape((int(X_train_actual.shape[1] / 1), 1), input_shape=(X_train_actual.shape[1], )))
# Set up the input layer, the first layer of convolution. Because you want to specify input_shape, it is released separately.#model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(Conv1D(filters=16, kernel_size=64, strides=16, padding='same',kernel_regularizer=regularizers.l2(1e-4)))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(MaxPooling1D(pool_size=2))
# second layer conv
model = wdcnn(filters=32, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid',  pool_size=2, BatchNormal=BatchNorm)
# Third layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fourth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='same',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Fifth layer conv
model = wdcnn(filters=64, kernerl_size=3, strides=1, conv_padding='valid',pool_padding='valid', pool_size=2, BatchNormal=BatchNorm)
# Flatten from convolution to full connection
model.add(Flatten())

# Flatten from convolution to full connection
model.add(Dense(units=100, activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
# Decrease the output layer
#model.add(Dense(units=num_classes, activation='softmax', kernel_regularizer=regularizers.l2(1e-4)))
model.add(Dense(classes, activation='softmax', name='y_pred'))


# this controls the learning rate
opt = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 2560, 1)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 160, 16)           1040
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 160, 16)           64
# _________________________________________________________________
# activation_5 (Activation)    (None, 160, 16)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 160, 32)           1568
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 160, 32)           128
# _________________________________________________________________
# activation_6 (Activation)    (None, 160, 32)           0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 80, 32)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 80, 64)            6208
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 80, 64)            256
# _________________________________________________________________
# activation_7 (Activation)    (None, 80, 64)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 40, 64)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 40, 64)            12352
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 40, 64)            256
# _________________________________________________________________
# activation_8 (Activation)    (None, 40, 64)            0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 20, 64)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 18, 64)            12352
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 18, 64)            256
# _________________________________________________________________
# activation_9 (Activation)    (None, 18, 64)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 9, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               57700
# _________________________________________________________________
# y_pred (Dense)               (None, 4)                 404
# =================================================================
# Total params: 92,584
# Trainable params: 92,104
# Non-trainable params: 480
# _________________________________________________________________

# %%
# !pip install plaidml-keras plaidbench
# Out:
# Collecting plaidml-keras
#   Using cached https://files.pythonhosted.org/packages/3e/f9/e385ba70f92083eb516834d927f788636231bfa0b8519855a5aa72d1363a/plaidml_keras-0.7.0-py2.py3-none-any.whl
# Collecting plaidbench
#   Downloading https://files.pythonhosted.org/packages/39/8e/36278a07583832fa8db1bf9b6643fdd89c8db8416191371c6ccfacacc03b/plaidbench-0.7.0-py2.py3-none-any.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 5.5MB/s eta 0:00:01
# Collecting keras==2.2.4 (from plaidml-keras)
#   Using cached https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl
# Collecting plaidml (from plaidml-keras)
#   Downloading https://files.pythonhosted.org/packages/b5/a6/e49225d5cf840e44ad6e658fe49f651e84f266bcf96641871f0f82c1814d/plaidml-0.7.0-py2.py3-none-macosx_10_10_x86_64.whl (17.8MB)
#      |████████████████████████████████| 17.8MB 8.6MB/s eta 0:00:01
# Requirement already satisfied: six in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidml-keras) (1.12.0)
# Requirement already satisfied: colorama in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidbench) (0.4.1)
# Collecting enum34>=1.1.6 (from plaidbench)
#   Downloading https://files.pythonhosted.org/packages/df/6e/46a0304561a07bda942c4283b67228d5b87d1ebd1189c866ede4b4cd6a0a/enum34-1.1.9-py3-none-any.whl
# Requirement already satisfied: h5py>=2.7.0 in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidbench) (2.9.0)
# Requirement already satisfied: numpy in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidbench) (1.17.2)
# Requirement already satisfied: click>=6.0.0 in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidbench) (7.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from keras==2.2.4->plaidml-keras) (1.0.8)
# Requirement already satisfied: pyyaml in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from keras==2.2.4->plaidml-keras) (5.1.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from keras==2.2.4->plaidml-keras) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from keras==2.2.4->plaidml-keras) (1.3.1)
# Requirement already satisfied: cffi in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from plaidml->plaidml-keras) (1.12.3)
# Requirement already satisfied: pycparser in /Users/opprud/opt/anaconda3/lib/python3.7/site-packages (from cffi->plaidml->plaidml-keras) (2.19)
# Installing collected packages: keras, enum34, plaidml, plaidml-keras, plaidbench
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed enum34-1.1.9 keras-2.2.4 plaidbench-0.7.0 plaidml-0.7.0 plaidml-keras-0.7.0

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
from sklearn.model_selection import train_test_split
from keras import utils

X_train, X_test, y_train, y_test = train_test_split(X_train_actual, y_train_actual, test_size=0.33, random_state=42)

print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train))
print(np.shape(y_test))



y_train_cat = utils.to_categorical(
    y_train,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)

y_test_cat = utils.to_categorical(
    y_test,
    #num_classes=(1+max(d1.y_train)),
    num_classes= 4,
    dtype='float32'
)
# Out:
# (7906, 2560)
# (3895, 2560)
# (7906,)
# (3895,)
# Using plaidml.keras.backend backend.

# %%
history = model.fit(X_train, y_train_cat, batch_size=50, epochs=100, validation_data=(X_test, y_test_cat))
# Out:
# Train on 7906 samples, validate on 3895 samples
# Epoch 1/100
# 7906/7906 [==============================] - 24s 3ms/sample - loss: 0.1836 - accuracy: 0.9423 - val_loss: 3.4855 - val_accuracy: 0.3112
# Epoch 2/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0506 - accuracy: 0.9949 - val_loss: 3.1811 - val_accuracy: 0.6128
# Epoch 3/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0391 - accuracy: 0.9991 - val_loss: 0.4414 - val_accuracy: 0.8624
# Epoch 4/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0362 - accuracy: 0.9999 - val_loss: 0.0418 - val_accuracy: 0.9979
# Epoch 5/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 6/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0341 - accuracy: 0.9995 - val_loss: 0.0328 - val_accuracy: 0.9997
# Epoch 7/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 8/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0309 - accuracy: 0.9999 - val_loss: 0.0304 - val_accuracy: 0.9995
# Epoch 9/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0422 - accuracy: 0.9963 - val_loss: 0.0426 - val_accuracy: 0.9954
# Epoch 10/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0404 - accuracy: 0.9970 - val_loss: 0.0316 - val_accuracy: 0.9995
# Epoch 11/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0321 - accuracy: 0.9989 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 12/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0293 - accuracy: 0.9999 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 13/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0418 - accuracy: 0.9961 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 14/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0308 - accuracy: 0.9996 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 15/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0565 - accuracy: 0.9904 - val_loss: 0.0301 - val_accuracy: 0.9995
# Epoch 16/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0291 - accuracy: 0.9997 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 17/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0294 - accuracy: 0.9990 - val_loss: 0.0271 - val_accuracy: 0.9997
# Epoch 18/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 19/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0253 - accuracy: 0.9997 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 20/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 21/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 22/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 23/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0220 - accuracy: 0.9997 - val_loss: 0.0218 - val_accuracy: 0.9992
# Epoch 24/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0406 - accuracy: 0.9948 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 25/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 26/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0230 - accuracy: 0.9996 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 27/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0384 - accuracy: 0.9956 - val_loss: 0.0223 - val_accuracy: 0.9997
# Epoch 28/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0364 - accuracy: 0.9957 - val_loss: 0.0355 - val_accuracy: 0.9967
# Epoch 29/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0225 - accuracy: 0.9997 - val_loss: 0.0220 - val_accuracy: 0.9997
# Epoch 30/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9995
# Epoch 31/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0202 - accuracy: 0.9999 - val_loss: 0.0199 - val_accuracy: 0.9997
# Epoch 32/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0197 - accuracy: 0.9999 - val_loss: 0.0197 - val_accuracy: 0.9997
# Epoch 33/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9997
# Epoch 34/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0178 - accuracy: 0.9999 - val_loss: 0.0176 - val_accuracy: 0.9997
# Epoch 35/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0176 - accuracy: 0.9997 - val_loss: 0.0173 - val_accuracy: 0.9995
# Epoch 36/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0163 - accuracy: 0.9999 - val_loss: 0.0211 - val_accuracy: 0.9985
# Epoch 37/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0289 - accuracy: 0.9972 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 38/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0184 - accuracy: 0.9996 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 39/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0254 - accuracy: 0.9977 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 40/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0252 - accuracy: 0.9978 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 41/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0187 - accuracy: 0.9999 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 42/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 43/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0163 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 44/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0157 - accuracy: 0.9999 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 45/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 46/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 47/100
# 7906/7906 [==============================] - 24s 3ms/sample - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 48/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0163 - accuracy: 0.9990 - val_loss: 0.0260 - val_accuracy: 0.9946
# Epoch 49/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0164 - accuracy: 0.9989 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 50/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0130 - accuracy: 0.9997 - val_loss: 0.0122 - val_accuracy: 0.9997
# Epoch 51/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0203 - accuracy: 0.9976 - val_loss: 0.0138 - val_accuracy: 0.9997
# Epoch 52/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0214 - accuracy: 0.9968 - val_loss: 0.8720 - val_accuracy: 0.8537
# Epoch 53/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0253 - accuracy: 0.9965 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 54/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0156 - accuracy: 0.9997 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 55/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0146 - accuracy: 0.9997 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 56/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0161 - accuracy: 0.9997 - val_loss: 0.0143 - val_accuracy: 0.9995
# Epoch 57/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0282 - accuracy: 0.9958 - val_loss: 0.0992 - val_accuracy: 0.9746
# Epoch 58/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0163 - accuracy: 0.9992 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 59/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0148 - accuracy: 0.9995 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 60/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0261 - accuracy: 0.9968 - val_loss: 0.0155 - val_accuracy: 0.9997
# Epoch 61/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0155 - accuracy: 0.9997 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 62/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0191 - accuracy: 0.9987 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 63/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0156 - accuracy: 0.9995 - val_loss: 0.0191 - val_accuracy: 0.9985
# Epoch 64/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0146 - accuracy: 0.9999 - val_loss: 0.0143 - val_accuracy: 0.9997
# Epoch 65/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0144 - accuracy: 0.9996 - val_loss: 0.0137 - val_accuracy: 0.9997
# Epoch 66/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0159 - accuracy: 0.9989 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 67/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0131 - accuracy: 0.9997 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 68/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 69/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0122 - accuracy: 0.9996 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 70/100
# 7906/7906 [==============================] - 23s 3ms/sample - loss: 0.0118 - accuracy: 0.9995 - val_loss: 0.0112 - val_accuracy: 0.9997
# Epoch 71/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0111 - accuracy: 0.9999 - val_loss: 0.0110 - val_accuracy: 0.9997
# Epoch 72/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0108 - accuracy: 0.9999 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 73/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0160 - accuracy: 0.9987 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 74/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0103 - accuracy: 0.9999 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 75/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 76/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 77/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 78/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 79/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 80/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 81/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0080 - accuracy: 0.9995 - val_loss: 0.0152 - val_accuracy: 0.9974
# Epoch 82/100
# 7906/7906 [==============================] - 20s 3ms/sample - loss: 0.0111 - accuracy: 0.9982 - val_loss: 10.9411 - val_accuracy: 0.4678
# Epoch 83/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0323 - accuracy: 0.9957 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 84/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0115 - accuracy: 0.9996 - val_loss: 0.0118 - val_accuracy: 0.9997
# Epoch 85/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 86/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.0165 - val_accuracy: 0.9972
# Epoch 87/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0101 - accuracy: 0.9999 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 88/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0138 - accuracy: 0.9986 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 89/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0187 - accuracy: 0.9976 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 90/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 91/100
# 7906/7906 [==============================] - 18s 2ms/sample - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 92/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0131 - accuracy: 0.9991 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 93/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0132 - accuracy: 0.9992 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 94/100
# 7906/7906 [==============================] - 19s 2ms/sample - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 95/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 96/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0129 - accuracy: 0.9987 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 97/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0098 - accuracy: 0.9999 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 98/100
# 7906/7906 [==============================] - 21s 3ms/sample - loss: 0.0156 - accuracy: 0.9980 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 99/100
# 7906/7906 [==============================] - 20s 2ms/sample - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 100/100
# 7906/7906 [==============================] - 22s 3ms/sample - loss: 0.0093 - accuracy: 0.9999 - val_loss: 0.0086 - val_accuracy: 1.0000

# %%
#X_test
# Evaluate the model on the test data using `evaluate`
print('\n# Evaluate on test data')
results = model.evaluate(X_test, y_test_cat, batch_size=128)
#results = model.evaluate(X_test, Y_test, batch_size=50)
print('test loss, test acc:', results)
# Out:
# # Evaluate on test data
# 3895/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test loss, test acc: [0.008592021200370727, 1.0]

# %% [markdown]
#  2s 565us/sample - loss: 0.0092 - accuracy: 1.0000
# test loss, test acc: [0.009345386033358868, 1.0]

# %%
# import for showing the confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

results = model.predict(X_test, 128)# batch_size=HParams.test_batch_size)

# convert from class probabilities to actual class predictions
predicted_classes = np.argmax(results, axis=1)

# Names of predicted classes
class_names = [ "OK", "Outer", "Inner", "Combined"]
#Labels 1 = healthy bearing, 2 = outer ring damage , 3 = inner ring damage, 4 = combined damage


# Generate the confusion matrix
cnf_matrix = confusion_matrix(y_test, predicted_classes)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[1204    0    0]
#  [   0 1183    0]
#  [   0    0 1508]]

# %% [markdown]
# ### Conclusion on the results
# The above model was trained with a larger size first input layer of 2560, and accordingly shape of the first input layer <br>
# This corresponds to exactly 1/1 of a full resolution when sampling at 64KHz, and therefore inne ring damages are seen more as distinct, since the damage will not roll through the load zone every time.<br>
# In this experiment actual HALT fault data is used
#
# The model may overfit the dat since __no__ misclassifications are done.
#
# This model was build with :
# * Total params: 92,584
# * Trainable params: 92,104
# * Non-trainable params: 480
#
# And a result of :
#
# **2s 565us/sample - loss: 0.0092 - accuracy: 1.0000 test loss, test acc: [0.009345386033358868, 1.0]**
